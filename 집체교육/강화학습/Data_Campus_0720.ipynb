# %%
import gym
import collections
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#Hyperparameters
learning_rate = 0.0005
gamma = 0.98
buffer_limit = 50000
batch_size = 32

class ReplayBuffer():
  def __init__(self):
    self.buffer = collections.deque(maxlen=buffer_limit)

  def put(self,transition):
    self.buffer.append(transition)

  def sample(self,n):
    mini_batch = random.sample(self.buffer,n)
    s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [],[],[],[],[]

    for transition in mini_batch:
      s,a,r,s_prime,done_mask = transition
      s_lst.append(s)
      a_lst.append([a])
      r_lst.append([r])
      s_prime_lst.append(s_prime)
      done_mask_lst.append([done_mask])
    return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), torch.tensor(r_lst), torch.tensor(s_prime_lst,dtype = torch.float), torch.tensor(done_mask_lst)

  def size(self):
    return len(self.buffer)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class Qnet(nn.Module):
  def __init__(self):
    super(Qnet,self).__init__()
    self.fc1 = nn.Linear(4,128)
    self.fc2 = nn.Linear(128,128)
    self.fc3 = nn.Linear(128,2)

  def forward(self,x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

  def sample_action(self,obs,epsilon):
    out = self.forward(obs)
    coin = random.random()
    if coin <epsilon :
      return random.randint(0,1)
    else :
      return out.argmax().item()

def train(q, q_target, memory, optimizer):
  for i in range(10):
    s,a,r,s_prime,done_mask = memory.sample(batch_size)
    q_out = q(s)
    q_a = q_out.gather(1,a)
    max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
    target = r + gamma * max_q_prime * done_mask
    loss = F.smooth_l1_loss(q_a,target)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

def main():
  env = gym.make('CartPole-v1')
  q = Qnet()
  q_target = Qnet()
  q_target.load_state_dict(q.state_dict())
  memory = ReplayBuffer()
  print_interval = 20
  score = 0.0
  optimizer = optim.Adam(q.parameters(),lr=learning_rate)
  for n_epi in range(10000):
    epsilon = max(0.01,0.08-0.01*(n_epi/200)) #Linear annealing from 8% to 1%
    s=env.reset()
    done=False
    while not done :
      a=q.sample_action(torch.from_numpy(s).float(),epsilon)
      s_prime,r,done,info = env.step(a)
      done_mask = 0.0 if done else 1.0
      memory.put((s,a,r/100.0, s_prime, done_mask))
      s=s_prime
      score +=r
      if done:
        break

    if memory.size()>2000:
      train(q,q_target,memory,optimizer)

    if n_epi%print_interval ==0 and n_epi!=0:
      q_target.load_state_dict(q.state_dict())
      print("n_episode:{},score:{:.1f},n_buffer:{},eps:{:.1f}%".format(n_epi, score/print_interval , memory.size(), epsilon*100))
      score = 0.0

  env.close()

if __name__ == '__main__':
  main()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# n_episode:20,score:10.3,n_buffer:206,eps:7.9%
# n_episode:40,score:9.4,n_buffer:395,eps:7.8%
# n_episode:60,score:9.7,n_buffer:588,eps:7.7%
# n_episode:80,score:9.6,n_buffer:779,eps:7.6%
# n_episode:100,score:9.3,n_buffer:965,eps:7.5%
# n_episode:120,score:9.7,n_buffer:1159,eps:7.4%
# n_episode:140,score:9.7,n_buffer:1353,eps:7.3%
# n_episode:160,score:9.6,n_buffer:1545,eps:7.2%
# n_episode:180,score:9.4,n_buffer:1734,eps:7.1%
# n_episode:200,score:9.8,n_buffer:1931,eps:7.0%
# n_episode:220,score:10.1,n_buffer:2133,eps:6.9%
# n_episode:240,score:9.8,n_buffer:2330,eps:6.8%
# n_episode:260,score:9.7,n_buffer:2524,eps:6.7%
# n_episode:280,score:10.5,n_buffer:2734,eps:6.6%
# n_episode:300,score:13.2,n_buffer:2997,eps:6.5%
# n_episode:320,score:17.2,n_buffer:3342,eps:6.4%
# n_episode:340,score:31.2,n_buffer:3967,eps:6.3%
# n_episode:360,score:38.9,n_buffer:4744,eps:6.2%
# n_episode:380,score:142.3,n_buffer:7591,eps:6.1%
# n_episode:400,score:166.8,n_buffer:10927,eps:6.0%
# n_episode:420,score:164.9,n_buffer:14225,eps:5.9%
# n_episode:440,score:192.7,n_buffer:18079,eps:5.8%
# n_episode:460,score:203.3,n_buffer:22145,eps:5.7%
# n_episode:480,score:211.4,n_buffer:26374,eps:5.6%
# n_episode:500,score:213.1,n_buffer:30635,eps:5.5%
# n_episode:520,score:263.4,n_buffer:35902,eps:5.4%
# n_episode:540,score:186.3,n_buffer:39628,eps:5.3%
# n_episode:560,score:200.8,n_buffer:43643,eps:5.2%
# n_episode:580,score:203.8,n_buffer:47720,eps:5.1%
# n_episode:600,score:256.0,n_buffer:50000,eps:5.0%
# n_episode:620,score:252.6,n_buffer:50000,eps:4.9%
# n_episode:640,score:262.6,n_buffer:50000,eps:4.8%
# n_episode:660,score:219.4,n_buffer:50000,eps:4.7%
# n_episode:680,score:229.9,n_buffer:50000,eps:4.6%
# n_episode:700,score:272.7,n_buffer:50000,eps:4.5%
# n_episode:720,score:175.7,n_buffer:50000,eps:4.4%
# n_episode:740,score:236.0,n_buffer:50000,eps:4.3%
# n_episode:760,score:202.2,n_buffer:50000,eps:4.2%
# n_episode:780,score:197.6,n_buffer:50000,eps:4.1%
# n_episode:800,score:171.1,n_buffer:50000,eps:4.0%
# n_episode:820,score:204.8,n_buffer:50000,eps:3.9%
# n_episode:840,score:264.6,n_buffer:50000,eps:3.8%
# n_episode:860,score:192.0,n_buffer:50000,eps:3.7%
# n_episode:880,score:239.3,n_buffer:50000,eps:3.6%
# n_episode:900,score:213.2,n_buffer:50000,eps:3.5%
# n_episode:920,score:319.7,n_buffer:50000,eps:3.4%
# n_episode:940,score:271.1,n_buffer:50000,eps:3.3%
# n_episode:960,score:203.8,n_buffer:50000,eps:3.2%
# n_episode:980,score:214.3,n_buffer:50000,eps:3.1%
# n_episode:1000,score:220.1,n_buffer:50000,eps:3.0%
# n_episode:1020,score:294.6,n_buffer:50000,eps:2.9%
# n_episode:1040,score:270.8,n_buffer:50000,eps:2.8%
# n_episode:1060,score:174.7,n_buffer:50000,eps:2.7%
# n_episode:1080,score:192.6,n_buffer:50000,eps:2.6%
# n_episode:1100,score:206.1,n_buffer:50000,eps:2.5%
# n_episode:1120,score:277.1,n_buffer:50000,eps:2.4%
# n_episode:1140,score:292.7,n_buffer:50000,eps:2.3%
# n_episode:1160,score:331.1,n_buffer:50000,eps:2.2%
# n_episode:1180,score:258.4,n_buffer:50000,eps:2.1%
# n_episode:1200,score:143.5,n_buffer:50000,eps:2.0%
# n_episode:1220,score:209.6,n_buffer:50000,eps:1.9%
# n_episode:1240,score:243.3,n_buffer:50000,eps:1.8%
# n_episode:1260,score:218.8,n_buffer:50000,eps:1.7%
# n_episode:1280,score:293.6,n_buffer:50000,eps:1.6%
# n_episode:1300,score:302.6,n_buffer:50000,eps:1.5%
# n_episode:1320,score:218.2,n_buffer:50000,eps:1.4%
# n_episode:1340,score:334.6,n_buffer:50000,eps:1.3%
# n_episode:1360,score:336.7,n_buffer:50000,eps:1.2%
# n_episode:1380,score:363.1,n_buffer:50000,eps:1.1%
# n_episode:1400,score:290.2,n_buffer:50000,eps:1.0%
# n_episode:1420,score:283.6,n_buffer:50000,eps:1.0%
# n_episode:1440,score:320.5,n_buffer:50000,eps:1.0%
# n_episode:1460,score:302.2,n_buffer:50000,eps:1.0%
# n_episode:1480,score:361.4,n_buffer:50000,eps:1.0%
# n_episode:1500,score:354.7,n_buffer:50000,eps:1.0%
# n_episode:1520,score:413.4,n_buffer:50000,eps:1.0%
# n_episode:1540,score:280.4,n_buffer:50000,eps:1.0%
# n_episode:1560,score:253.8,n_buffer:50000,eps:1.0%
# n_episode:1580,score:320.1,n_buffer:50000,eps:1.0%
# n_episode:1600,score:321.1,n_buffer:50000,eps:1.0%
# n_episode:1620,score:313.9,n_buffer:50000,eps:1.0%
# n_episode:1640,score:427.2,n_buffer:50000,eps:1.0%
# n_episode:1660,score:382.6,n_buffer:50000,eps:1.0%
# n_episode:1680,score:430.2,n_buffer:50000,eps:1.0%
# n_episode:1700,score:340.6,n_buffer:50000,eps:1.0%
# n_episode:1720,score:380.4,n_buffer:50000,eps:1.0%
# n_episode:1740,score:411.1,n_buffer:50000,eps:1.0%
# n_episode:1760,score:384.4,n_buffer:50000,eps:1.0%
# n_episode:1780,score:321.4,n_buffer:50000,eps:1.0%
# n_episode:1800,score:470.2,n_buffer:50000,eps:1.0%
# n_episode:1820,score:340.6,n_buffer:50000,eps:1.0%
# n_episode:1840,score:320.2,n_buffer:50000,eps:1.0%
# n_episode:1860,score:245.7,n_buffer:50000,eps:1.0%
# n_episode:1880,score:213.2,n_buffer:50000,eps:1.0%
# n_episode:1900,score:118.0,n_buffer:50000,eps:1.0%
# n_episode:1920,score:184.1,n_buffer:50000,eps:1.0%
# n_episode:1940,score:214.4,n_buffer:50000,eps:1.0%
# n_episode:1960,score:217.1,n_buffer:50000,eps:1.0%
# n_episode:1980,score:185.8,n_buffer:50000,eps:1.0%
# n_episode:2000,score:237.7,n_buffer:50000,eps:1.0%
# n_episode:2020,score:304.6,n_buffer:50000,eps:1.0%
# n_episode:2040,score:290.8,n_buffer:50000,eps:1.0%
# n_episode:2060,score:303.1,n_buffer:50000,eps:1.0%
# n_episode:2080,score:87.4,n_buffer:50000,eps:1.0%
# n_episode:2100,score:221.0,n_buffer:50000,eps:1.0%
# n_episode:2120,score:381.0,n_buffer:50000,eps:1.0%
# n_episode:2140,score:335.4,n_buffer:50000,eps:1.0%
# n_episode:2160,score:404.9,n_buffer:50000,eps:1.0%
# n_episode:2180,score:419.4,n_buffer:50000,eps:1.0%
# n_episode:2200,score:288.7,n_buffer:50000,eps:1.0%
# n_episode:2220,score:328.9,n_buffer:50000,eps:1.0%
# n_episode:2240,score:375.3,n_buffer:50000,eps:1.0%
# n_episode:2260,score:359.7,n_buffer:50000,eps:1.0%
# n_episode:2280,score:372.9,n_buffer:50000,eps:1.0%
# n_episode:2300,score:494.2,n_buffer:50000,eps:1.0%
# n_episode:2320,score:335.9,n_buffer:50000,eps:1.0%
# n_episode:2340,score:433.4,n_buffer:50000,eps:1.0%
# n_episode:2360,score:347.1,n_buffer:50000,eps:1.0%
# n_episode:2380,score:361.1,n_buffer:50000,eps:1.0%
# n_episode:2400,score:296.9,n_buffer:50000,eps:1.0%
# n_episode:2420,score:191.5,n_buffer:50000,eps:1.0%
# n_episode:2440,score:306.4,n_buffer:50000,eps:1.0%
# n_episode:2460,score:289.9,n_buffer:50000,eps:1.0%
# n_episode:2480,score:262.4,n_buffer:50000,eps:1.0%
# n_episode:2500,score:299.9,n_buffer:50000,eps:1.0%
# n_episode:2520,score:223.4,n_buffer:50000,eps:1.0%
# n_episode:2540,score:265.4,n_buffer:50000,eps:1.0%
# n_episode:2560,score:269.5,n_buffer:50000,eps:1.0%
# n_episode:2580,score:301.4,n_buffer:50000,eps:1.0%
# n_episode:2600,score:251.1,n_buffer:50000,eps:1.0%
# n_episode:2620,score:321.1,n_buffer:50000,eps:1.0%
# n_episode:2640,score:327.4,n_buffer:50000,eps:1.0%
# n_episode:2660,score:279.3,n_buffer:50000,eps:1.0%
# n_episode:2680,score:151.8,n_buffer:50000,eps:1.0%
# n_episode:2700,score:195.2,n_buffer:50000,eps:1.0%
# n_episode:2720,score:284.5,n_buffer:50000,eps:1.0%
# n_episode:2740,score:227.2,n_buffer:50000,eps:1.0%
# n_episode:2760,score:303.2,n_buffer:50000,eps:1.0%
# n_episode:2780,score:150.6,n_buffer:50000,eps:1.0%
# n_episode:2800,score:194.6,n_buffer:50000,eps:1.0%
# n_episode:2820,score:338.1,n_buffer:50000,eps:1.0%
# n_episode:2840,score:203.2,n_buffer:50000,eps:1.0%
# n_episode:2860,score:258.1,n_buffer:50000,eps:1.0%
# n_episode:2880,score:371.8,n_buffer:50000,eps:1.0%
# n_episode:2900,score:341.9,n_buffer:50000,eps:1.0%
# n_episode:2920,score:175.5,n_buffer:50000,eps:1.0%
# n_episode:2940,score:276.9,n_buffer:50000,eps:1.0%
# n_episode:2960,score:239.7,n_buffer:50000,eps:1.0%
# n_episode:2980,score:235.8,n_buffer:50000,eps:1.0%
# n_episode:3000,score:316.6,n_buffer:50000,eps:1.0%
# n_episode:3020,score:287.6,n_buffer:50000,eps:1.0%
# n_episode:3040,score:314.4,n_buffer:50000,eps:1.0%
# n_episode:3060,score:418.5,n_buffer:50000,eps:1.0%
# n_episode:3080,score:358.2,n_buffer:50000,eps:1.0%
# n_episode:3100,score:467.2,n_buffer:50000,eps:1.0%
# n_episode:3120,score:389.7,n_buffer:50000,eps:1.0%
# n_episode:3140,score:457.1,n_buffer:50000,eps:1.0%
# n_episode:3160,score:316.4,n_buffer:50000,eps:1.0%
# n_episode:3180,score:389.9,n_buffer:50000,eps:1.0%
# n_episode:3200,score:403.9,n_buffer:50000,eps:1.0%
# n_episode:3220,score:372.3,n_buffer:50000,eps:1.0%
# n_episode:3240,score:289.1,n_buffer:50000,eps:1.0%
# n_episode:3260,score:303.8,n_buffer:50000,eps:1.0%
# n_episode:3280,score:297.7,n_buffer:50000,eps:1.0%
# n_episode:3300,score:315.2,n_buffer:50000,eps:1.0%
# n_episode:3320,score:320.2,n_buffer:50000,eps:1.0%
# n_episode:3340,score:331.1,n_buffer:50000,eps:1.0%
# n_episode:3360,score:247.1,n_buffer:50000,eps:1.0%
# n_episode:3380,score:219.8,n_buffer:50000,eps:1.0%
# n_episode:3400,score:299.0,n_buffer:50000,eps:1.0%
# n_episode:3420,score:306.0,n_buffer:50000,eps:1.0%
# n_episode:3440,score:294.8,n_buffer:50000,eps:1.0%
# n_episode:3460,score:485.2,n_buffer:50000,eps:1.0%
# n_episode:3480,score:434.4,n_buffer:50000,eps:1.0%
# n_episode:3500,score:177.5,n_buffer:50000,eps:1.0%
# n_episode:3520,score:173.9,n_buffer:50000,eps:1.0%
# n_episode:3540,score:243.9,n_buffer:50000,eps:1.0%
# n_episode:3560,score:215.6,n_buffer:50000,eps:1.0%
# n_episode:3580,score:283.5,n_buffer:50000,eps:1.0%
# n_episode:3600,score:276.8,n_buffer:50000,eps:1.0%
# n_episode:3620,score:294.1,n_buffer:50000,eps:1.0%
# n_episode:3640,score:286.2,n_buffer:50000,eps:1.0%
# n_episode:3660,score:327.8,n_buffer:50000,eps:1.0%
# n_episode:3680,score:349.6,n_buffer:50000,eps:1.0%
# n_episode:3700,score:439.5,n_buffer:50000,eps:1.0%
# n_episode:3720,score:432.6,n_buffer:50000,eps:1.0%
# n_episode:3740,score:373.1,n_buffer:50000,eps:1.0%
# n_episode:3760,score:415.9,n_buffer:50000,eps:1.0%
# n_episode:3780,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:3800,score:402.6,n_buffer:50000,eps:1.0%
# n_episode:3820,score:418.4,n_buffer:50000,eps:1.0%
# n_episode:3840,score:413.1,n_buffer:50000,eps:1.0%
# n_episode:3860,score:465.9,n_buffer:50000,eps:1.0%
# n_episode:3880,score:478.1,n_buffer:50000,eps:1.0%
# n_episode:3900,score:442.6,n_buffer:50000,eps:1.0%
# n_episode:3920,score:398.4,n_buffer:50000,eps:1.0%
# n_episode:3940,score:461.9,n_buffer:50000,eps:1.0%
# n_episode:3960,score:444.1,n_buffer:50000,eps:1.0%
# n_episode:3980,score:427.8,n_buffer:50000,eps:1.0%
# n_episode:4000,score:419.9,n_buffer:50000,eps:1.0%
# n_episode:4020,score:425.2,n_buffer:50000,eps:1.0%
# n_episode:4040,score:457.9,n_buffer:50000,eps:1.0%
# n_episode:4060,score:335.9,n_buffer:50000,eps:1.0%
# n_episode:4080,score:387.6,n_buffer:50000,eps:1.0%
# n_episode:4100,score:416.5,n_buffer:50000,eps:1.0%
# n_episode:4120,score:260.1,n_buffer:50000,eps:1.0%
# n_episode:4140,score:375.6,n_buffer:50000,eps:1.0%
# n_episode:4160,score:283.1,n_buffer:50000,eps:1.0%
# n_episode:4180,score:450.4,n_buffer:50000,eps:1.0%
# n_episode:4200,score:442.9,n_buffer:50000,eps:1.0%
# n_episode:4220,score:367.8,n_buffer:50000,eps:1.0%
# n_episode:4240,score:371.3,n_buffer:50000,eps:1.0%
# n_episode:4260,score:363.9,n_buffer:50000,eps:1.0%
# n_episode:4280,score:396.8,n_buffer:50000,eps:1.0%
# n_episode:4300,score:422.4,n_buffer:50000,eps:1.0%
# n_episode:4320,score:413.5,n_buffer:50000,eps:1.0%
# n_episode:4340,score:398.4,n_buffer:50000,eps:1.0%
# n_episode:4360,score:395.1,n_buffer:50000,eps:1.0%
# n_episode:4380,score:362.7,n_buffer:50000,eps:1.0%
# n_episode:4400,score:396.8,n_buffer:50000,eps:1.0%
# n_episode:4420,score:320.8,n_buffer:50000,eps:1.0%
# n_episode:4440,score:270.0,n_buffer:50000,eps:1.0%
# n_episode:4460,score:369.3,n_buffer:50000,eps:1.0%
# n_episode:4480,score:250.2,n_buffer:50000,eps:1.0%
# n_episode:4500,score:314.7,n_buffer:50000,eps:1.0%
# n_episode:4520,score:321.3,n_buffer:50000,eps:1.0%
# n_episode:4540,score:360.8,n_buffer:50000,eps:1.0%
# n_episode:4560,score:325.1,n_buffer:50000,eps:1.0%
# n_episode:4580,score:180.4,n_buffer:50000,eps:1.0%
# n_episode:4600,score:283.1,n_buffer:50000,eps:1.0%
# n_episode:4620,score:447.6,n_buffer:50000,eps:1.0%
# n_episode:4640,score:440.2,n_buffer:50000,eps:1.0%
# n_episode:4660,score:413.5,n_buffer:50000,eps:1.0%
# n_episode:4680,score:477.6,n_buffer:50000,eps:1.0%
# n_episode:4700,score:360.4,n_buffer:50000,eps:1.0%
# n_episode:4720,score:398.1,n_buffer:50000,eps:1.0%
# n_episode:4740,score:406.9,n_buffer:50000,eps:1.0%
# n_episode:4760,score:474.2,n_buffer:50000,eps:1.0%
# n_episode:4780,score:471.4,n_buffer:50000,eps:1.0%
# n_episode:4800,score:467.8,n_buffer:50000,eps:1.0%
# n_episode:4820,score:465.1,n_buffer:50000,eps:1.0%
# n_episode:4840,score:437.0,n_buffer:50000,eps:1.0%
# n_episode:4860,score:369.6,n_buffer:50000,eps:1.0%
# n_episode:4880,score:389.7,n_buffer:50000,eps:1.0%
# n_episode:4900,score:337.2,n_buffer:50000,eps:1.0%
# n_episode:4920,score:326.8,n_buffer:50000,eps:1.0%
# n_episode:4940,score:128.3,n_buffer:50000,eps:1.0%
# n_episode:4960,score:20.0,n_buffer:50000,eps:1.0%
# n_episode:4980,score:97.7,n_buffer:50000,eps:1.0%
# n_episode:5000,score:232.2,n_buffer:50000,eps:1.0%
# n_episode:5020,score:378.4,n_buffer:50000,eps:1.0%
# n_episode:5040,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:5060,score:482.9,n_buffer:50000,eps:1.0%
# n_episode:5080,score:394.8,n_buffer:50000,eps:1.0%
# n_episode:5100,score:428.1,n_buffer:50000,eps:1.0%
# n_episode:5120,score:476.5,n_buffer:50000,eps:1.0%
# n_episode:5140,score:487.6,n_buffer:50000,eps:1.0%
# n_episode:5160,score:474.8,n_buffer:50000,eps:1.0%
# n_episode:5180,score:346.8,n_buffer:50000,eps:1.0%
# n_episode:5200,score:418.8,n_buffer:50000,eps:1.0%
# n_episode:5220,score:379.2,n_buffer:50000,eps:1.0%
# n_episode:5240,score:488.0,n_buffer:50000,eps:1.0%
# n_episode:5260,score:459.5,n_buffer:50000,eps:1.0%
# n_episode:5280,score:343.5,n_buffer:50000,eps:1.0%
# n_episode:5300,score:337.1,n_buffer:50000,eps:1.0%
# n_episode:5320,score:455.6,n_buffer:50000,eps:1.0%
# n_episode:5340,score:338.2,n_buffer:50000,eps:1.0%
# n_episode:5360,score:354.9,n_buffer:50000,eps:1.0%
# n_episode:5380,score:401.4,n_buffer:50000,eps:1.0%
# n_episode:5400,score:260.3,n_buffer:50000,eps:1.0%
# n_episode:5420,score:433.8,n_buffer:50000,eps:1.0%
# n_episode:5440,score:404.9,n_buffer:50000,eps:1.0%
# n_episode:5460,score:389.9,n_buffer:50000,eps:1.0%
# n_episode:5480,score:304.1,n_buffer:50000,eps:1.0%
# n_episode:5500,score:413.4,n_buffer:50000,eps:1.0%
# n_episode:5520,score:416.3,n_buffer:50000,eps:1.0%
# n_episode:5540,score:361.0,n_buffer:50000,eps:1.0%
# n_episode:5560,score:293.4,n_buffer:50000,eps:1.0%
# n_episode:5580,score:393.4,n_buffer:50000,eps:1.0%
# n_episode:5600,score:422.1,n_buffer:50000,eps:1.0%
# n_episode:5620,score:408.6,n_buffer:50000,eps:1.0%
# n_episode:5640,score:451.7,n_buffer:50000,eps:1.0%
# n_episode:5660,score:448.9,n_buffer:50000,eps:1.0%
# n_episode:5680,score:387.8,n_buffer:50000,eps:1.0%
# n_episode:5700,score:419.6,n_buffer:50000,eps:1.0%
# n_episode:5720,score:395.1,n_buffer:50000,eps:1.0%
# n_episode:5740,score:283.9,n_buffer:50000,eps:1.0%
# n_episode:5760,score:378.2,n_buffer:50000,eps:1.0%
# n_episode:5780,score:286.1,n_buffer:50000,eps:1.0%
# n_episode:5800,score:363.1,n_buffer:50000,eps:1.0%
# n_episode:5820,score:296.9,n_buffer:50000,eps:1.0%
# n_episode:5840,score:253.5,n_buffer:50000,eps:1.0%
# n_episode:5860,score:356.0,n_buffer:50000,eps:1.0%
# n_episode:5880,score:440.9,n_buffer:50000,eps:1.0%
# n_episode:5900,score:333.9,n_buffer:50000,eps:1.0%
# n_episode:5920,score:382.6,n_buffer:50000,eps:1.0%
# n_episode:5940,score:351.8,n_buffer:50000,eps:1.0%
# n_episode:5960,score:304.9,n_buffer:50000,eps:1.0%
# n_episode:5980,score:354.7,n_buffer:50000,eps:1.0%
# n_episode:6000,score:332.4,n_buffer:50000,eps:1.0%
# n_episode:6020,score:322.9,n_buffer:50000,eps:1.0%
# n_episode:6040,score:353.9,n_buffer:50000,eps:1.0%
# n_episode:6060,score:265.1,n_buffer:50000,eps:1.0%
# n_episode:6080,score:254.7,n_buffer:50000,eps:1.0%
# n_episode:6100,score:244.4,n_buffer:50000,eps:1.0%
# n_episode:6120,score:350.8,n_buffer:50000,eps:1.0%
# n_episode:6140,score:466.7,n_buffer:50000,eps:1.0%
# n_episode:6160,score:482.9,n_buffer:50000,eps:1.0%
# n_episode:6180,score:428.8,n_buffer:50000,eps:1.0%
# n_episode:6200,score:413.4,n_buffer:50000,eps:1.0%
# n_episode:6220,score:402.6,n_buffer:50000,eps:1.0%
# n_episode:6240,score:374.2,n_buffer:50000,eps:1.0%
# n_episode:6260,score:395.1,n_buffer:50000,eps:1.0%
# n_episode:6280,score:427.6,n_buffer:50000,eps:1.0%
# n_episode:6300,score:411.3,n_buffer:50000,eps:1.0%
# n_episode:6320,score:358.0,n_buffer:50000,eps:1.0%
# n_episode:6340,score:298.8,n_buffer:50000,eps:1.0%
# n_episode:6360,score:283.1,n_buffer:50000,eps:1.0%
# n_episode:6380,score:330.4,n_buffer:50000,eps:1.0%
# n_episode:6400,score:360.6,n_buffer:50000,eps:1.0%
# n_episode:6420,score:264.1,n_buffer:50000,eps:1.0%
# n_episode:6440,score:376.3,n_buffer:50000,eps:1.0%
# n_episode:6460,score:373.9,n_buffer:50000,eps:1.0%
# n_episode:6480,score:270.8,n_buffer:50000,eps:1.0%
# n_episode:6500,score:348.1,n_buffer:50000,eps:1.0%
# n_episode:6520,score:442.9,n_buffer:50000,eps:1.0%
# n_episode:6540,score:427.7,n_buffer:50000,eps:1.0%
# n_episode:6560,score:379.9,n_buffer:50000,eps:1.0%
# n_episode:6580,score:459.7,n_buffer:50000,eps:1.0%
# n_episode:6600,score:443.9,n_buffer:50000,eps:1.0%
# n_episode:6620,score:372.2,n_buffer:50000,eps:1.0%
# n_episode:6640,score:265.1,n_buffer:50000,eps:1.0%
# n_episode:6660,score:175.1,n_buffer:50000,eps:1.0%
# n_episode:6680,score:407.8,n_buffer:50000,eps:1.0%
# n_episode:6700,score:185.6,n_buffer:50000,eps:1.0%
# n_episode:6720,score:273.8,n_buffer:50000,eps:1.0%
# n_episode:6740,score:347.8,n_buffer:50000,eps:1.0%
# n_episode:6760,score:410.9,n_buffer:50000,eps:1.0%
# n_episode:6780,score:328.1,n_buffer:50000,eps:1.0%
# n_episode:6800,score:438.2,n_buffer:50000,eps:1.0%
# n_episode:6820,score:475.4,n_buffer:50000,eps:1.0%
# n_episode:6840,score:482.6,n_buffer:50000,eps:1.0%
# n_episode:6860,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:6880,score:499.1,n_buffer:50000,eps:1.0%
# n_episode:6900,score:460.4,n_buffer:50000,eps:1.0%
# n_episode:6920,score:406.7,n_buffer:50000,eps:1.0%
# n_episode:6940,score:288.4,n_buffer:50000,eps:1.0%
# n_episode:6960,score:297.9,n_buffer:50000,eps:1.0%
# n_episode:6980,score:396.7,n_buffer:50000,eps:1.0%
# n_episode:7000,score:480.7,n_buffer:50000,eps:1.0%
# n_episode:7020,score:433.2,n_buffer:50000,eps:1.0%
# n_episode:7040,score:384.4,n_buffer:50000,eps:1.0%
# n_episode:7060,score:402.2,n_buffer:50000,eps:1.0%
# n_episode:7080,score:421.2,n_buffer:50000,eps:1.0%
# n_episode:7100,score:312.4,n_buffer:50000,eps:1.0%
# n_episode:7120,score:453.1,n_buffer:50000,eps:1.0%
# n_episode:7140,score:409.4,n_buffer:50000,eps:1.0%
# n_episode:7160,score:456.0,n_buffer:50000,eps:1.0%
# n_episode:7180,score:460.9,n_buffer:50000,eps:1.0%
# n_episode:7200,score:364.8,n_buffer:50000,eps:1.0%
# n_episode:7220,score:303.2,n_buffer:50000,eps:1.0%
# n_episode:7240,score:279.0,n_buffer:50000,eps:1.0%
# n_episode:7260,score:186.7,n_buffer:50000,eps:1.0%
# n_episode:7280,score:336.3,n_buffer:50000,eps:1.0%
# n_episode:7300,score:453.1,n_buffer:50000,eps:1.0%
# n_episode:7320,score:433.1,n_buffer:50000,eps:1.0%
# n_episode:7340,score:374.9,n_buffer:50000,eps:1.0%
# n_episode:7360,score:413.2,n_buffer:50000,eps:1.0%
# n_episode:7380,score:441.1,n_buffer:50000,eps:1.0%
# n_episode:7400,score:492.4,n_buffer:50000,eps:1.0%
# n_episode:7420,score:439.9,n_buffer:50000,eps:1.0%
# n_episode:7440,score:399.9,n_buffer:50000,eps:1.0%
# n_episode:7460,score:423.4,n_buffer:50000,eps:1.0%
# n_episode:7480,score:389.9,n_buffer:50000,eps:1.0%
# n_episode:7500,score:419.7,n_buffer:50000,eps:1.0%
# n_episode:7520,score:341.9,n_buffer:50000,eps:1.0%
# n_episode:7540,score:418.6,n_buffer:50000,eps:1.0%
# n_episode:7560,score:408.5,n_buffer:50000,eps:1.0%
# n_episode:7580,score:470.1,n_buffer:50000,eps:1.0%
# n_episode:7600,score:404.4,n_buffer:50000,eps:1.0%
# n_episode:7620,score:455.3,n_buffer:50000,eps:1.0%
# n_episode:7640,score:494.4,n_buffer:50000,eps:1.0%
# n_episode:7660,score:443.5,n_buffer:50000,eps:1.0%
# n_episode:7680,score:451.9,n_buffer:50000,eps:1.0%
# n_episode:7700,score:475.6,n_buffer:50000,eps:1.0%
# n_episode:7720,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:7740,score:416.9,n_buffer:50000,eps:1.0%
# n_episode:7760,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:7780,score:461.4,n_buffer:50000,eps:1.0%
# n_episode:7800,score:297.2,n_buffer:50000,eps:1.0%
# n_episode:7820,score:393.8,n_buffer:50000,eps:1.0%
# n_episode:7840,score:484.6,n_buffer:50000,eps:1.0%
# n_episode:7860,score:469.1,n_buffer:50000,eps:1.0%
# n_episode:7880,score:441.6,n_buffer:50000,eps:1.0%
# n_episode:7900,score:490.9,n_buffer:50000,eps:1.0%
# n_episode:7920,score:453.1,n_buffer:50000,eps:1.0%
# n_episode:7940,score:469.2,n_buffer:50000,eps:1.0%
# n_episode:7960,score:441.1,n_buffer:50000,eps:1.0%
# n_episode:7980,score:378.1,n_buffer:50000,eps:1.0%
# n_episode:8000,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:8020,score:410.9,n_buffer:50000,eps:1.0%
# n_episode:8040,score:460.4,n_buffer:50000,eps:1.0%
# n_episode:8060,score:466.0,n_buffer:50000,eps:1.0%
# n_episode:8080,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:8100,score:500.0,n_buffer:50000,eps:1.0%
# n_episode:8120,score:476.1,n_buffer:50000,eps:1.0%
# n_episode:8140,score:483.5,n_buffer:50000,eps:1.0%
# n_episode:8160,score:430.8,n_buffer:50000,eps:1.0%
# n_episode:8180,score:481.6,n_buffer:50000,eps:1.0%
# n_episode:8200,score:437.9,n_buffer:50000,eps:1.0%
# n_episode:8220,score:354.6,n_buffer:50000,eps:1.0%
# n_episode:8240,score:368.6,n_buffer:50000,eps:1.0%
# n_episode:8260,score:485.9,n_buffer:50000,eps:1.0%
# n_episode:8280,score:470.3,n_buffer:50000,eps:1.0%
# n_episode:8300,score:324.1,n_buffer:50000,eps:1.0%
# n_episode:8320,score:397.0,n_buffer:50000,eps:1.0%
# n_episode:8340,score:463.1,n_buffer:50000,eps:1.0%
# n_episode:8360,score:479.9,n_buffer:50000,eps:1.0%
# n_episode:8380,score:431.3,n_buffer:50000,eps:1.0%
# n_episode:8400,score:448.9,n_buffer:50000,eps:1.0%
# n_episode:8420,score:461.9,n_buffer:50000,eps:1.0%
# n_episode:8440,score:465.8,n_buffer:50000,eps:1.0%
# n_episode:8460,score:439.9,n_buffer:50000,eps:1.0%
# n_episode:8480,score:297.2,n_buffer:50000,eps:1.0%
# n_episode:8500,score:357.4,n_buffer:50000,eps:1.0%
# n_episode:8520,score:409.2,n_buffer:50000,eps:1.0%
# n_episode:8540,score:475.6,n_buffer:50000,eps:1.0%
# n_episode:8560,score:471.1,n_buffer:50000,eps:1.0%
# n_episode:8580,score:458.8,n_buffer:50000,eps:1.0%
# n_episode:8600,score:442.5,n_buffer:50000,eps:1.0%
# n_episode:8620,score:482.1,n_buffer:50000,eps:1.0%
# n_episode:8640,score:480.9,n_buffer:50000,eps:1.0%
# n_episode:8660,score:422.0,n_buffer:50000,eps:1.0%
# n_episode:8680,score:404.6,n_buffer:50000,eps:1.0%
# n_episode:8700,score:245.2,n_buffer:50000,eps:1.0%
# n_episode:8720,score:132.9,n_buffer:50000,eps:1.0%
# n_episode:8740,score:135.7,n_buffer:50000,eps:1.0%
# n_episode:8760,score:120.7,n_buffer:50000,eps:1.0%
# n_episode:8780,score:135.0,n_buffer:50000,eps:1.0%
# n_episode:8800,score:117.0,n_buffer:50000,eps:1.0%
# n_episode:8820,score:106.5,n_buffer:50000,eps:1.0%
# n_episode:8840,score:145.0,n_buffer:50000,eps:1.0%
# n_episode:8860,score:138.1,n_buffer:50000,eps:1.0%
# n_episode:8880,score:121.3,n_buffer:50000,eps:1.0%
# n_episode:8900,score:129.1,n_buffer:50000,eps:1.0%
# n_episode:8920,score:175.2,n_buffer:50000,eps:1.0%
# n_episode:8940,score:176.3,n_buffer:50000,eps:1.0%
# n_episode:8960,score:242.2,n_buffer:50000,eps:1.0%
# n_episode:8980,score:191.1,n_buffer:50000,eps:1.0%
# n_episode:9000,score:287.4,n_buffer:50000,eps:1.0%
# n_episode:9020,score:222.2,n_buffer:50000,eps:1.0%
# n_episode:9040,score:366.2,n_buffer:50000,eps:1.0%
# n_episode:9060,score:447.5,n_buffer:50000,eps:1.0%
# n_episode:9080,score:462.2,n_buffer:50000,eps:1.0%
# n_episode:9100,score:353.2,n_buffer:50000,eps:1.0%
# n_episode:9120,score:438.8,n_buffer:50000,eps:1.0%
# n_episode:9140,score:432.6,n_buffer:50000,eps:1.0%
# n_episode:9160,score:448.4,n_buffer:50000,eps:1.0%
# n_episode:9180,score:414.1,n_buffer:50000,eps:1.0%
# n_episode:9200,score:455.9,n_buffer:50000,eps:1.0%
# n_episode:9220,score:440.1,n_buffer:50000,eps:1.0%
# n_episode:9240,score:345.1,n_buffer:50000,eps:1.0%
# n_episode:9260,score:345.2,n_buffer:50000,eps:1.0%
# n_episode:9280,score:266.9,n_buffer:50000,eps:1.0%
# n_episode:9300,score:188.7,n_buffer:50000,eps:1.0%
# n_episode:9320,score:214.9,n_buffer:50000,eps:1.0%
# n_episode:9340,score:378.2,n_buffer:50000,eps:1.0%
# n_episode:9360,score:372.9,n_buffer:50000,eps:1.0%
# n_episode:9380,score:425.2,n_buffer:50000,eps:1.0%
# n_episode:9400,score:400.6,n_buffer:50000,eps:1.0%
# n_episode:9420,score:393.9,n_buffer:50000,eps:1.0%
# n_episode:9440,score:286.1,n_buffer:50000,eps:1.0%
# n_episode:9460,score:360.4,n_buffer:50000,eps:1.0%
# n_episode:9480,score:426.4,n_buffer:50000,eps:1.0%
# n_episode:9500,score:346.1,n_buffer:50000,eps:1.0%
# n_episode:9520,score:416.1,n_buffer:50000,eps:1.0%
# n_episode:9540,score:282.4,n_buffer:50000,eps:1.0%
# n_episode:9560,score:191.1,n_buffer:50000,eps:1.0%
# n_episode:9580,score:208.1,n_buffer:50000,eps:1.0%
# n_episode:9600,score:187.4,n_buffer:50000,eps:1.0%
# n_episode:9620,score:238.3,n_buffer:50000,eps:1.0%
# n_episode:9640,score:235.2,n_buffer:50000,eps:1.0%
# n_episode:9660,score:167.5,n_buffer:50000,eps:1.0%
# n_episode:9680,score:144.4,n_buffer:50000,eps:1.0%
# n_episode:9700,score:190.2,n_buffer:50000,eps:1.0%
# n_episode:9720,score:178.8,n_buffer:50000,eps:1.0%
# n_episode:9740,score:133.9,n_buffer:50000,eps:1.0%
# n_episode:9760,score:119.2,n_buffer:50000,eps:1.0%
# n_episode:9780,score:134.4,n_buffer:50000,eps:1.0%
# n_episode:9800,score:186.7,n_buffer:50000,eps:1.0%
# n_episode:9820,score:156.8,n_buffer:50000,eps:1.0%
# n_episode:9840,score:172.8,n_buffer:50000,eps:1.0%
# n_episode:9860,score:174.1,n_buffer:50000,eps:1.0%
# n_episode:9880,score:308.8,n_buffer:50000,eps:1.0%
# n_episode:9900,score:288.4,n_buffer:50000,eps:1.0%
# n_episode:9920,score:375.6,n_buffer:50000,eps:1.0%
# n_episode:9940,score:404.1,n_buffer:50000,eps:1.0%
# n_episode:9960,score:494.8,n_buffer:50000,eps:1.0%
# n_episode:9980,score:500.0,n_buffer:50000,eps:1.0%

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma = 0.98
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self). __init__()
        self.data = []

        self.fc1 = nn. Linear(4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x

    def put_data(self, item):
        self.data.append(item)

    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma * R
            loss = -torch.log(prob) * R
            loss. backward()
        self.optimizer.step()
        self.data = []
def main() :
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20
    for n_epi in range (10000):
        s= env.reset()
        done = False
        while not done:
            prob = pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample()
            s_prime, r, done, info = env.step(a.item())
            pi.put_data((r,prob[a]))
            s = s_prime
            score += r
        pi.train_net()
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
        score = 0.0
    env.close()
if __name__ == '__main__' :
    main()
# Out:
# # of episode :20, avg score : 0.7
# # of episode :40, avg score : 1.15
# # of episode :60, avg score : 2.45
# # of episode :80, avg score : 1.5
# # of episode :100, avg score : 1.55
# # of episode :120, avg score : 0.7
# # of episode :140, avg score : 1.05
# # of episode :160, avg score : 1.0
# # of episode :180, avg score : 1.9
# # of episode :200, avg score : 0.6
# # of episode :220, avg score : 1.9
# # of episode :240, avg score : 2.25
# # of episode :260, avg score : 1.75
# # of episode :280, avg score : 2.25
# # of episode :300, avg score : 3.25
# # of episode :320, avg score : 2.05
# # of episode :340, avg score : 4.85
# # of episode :360, avg score : 1.15
# # of episode :380, avg score : 1.35
# # of episode :400, avg score : 2.4
# # of episode :420, avg score : 1.6
# # of episode :440, avg score : 3.3
# # of episode :460, avg score : 0.95
# # of episode :480, avg score : 2.95
# # of episode :500, avg score : 1.6
# # of episode :520, avg score : 4.85
# # of episode :540, avg score : 2.3
# # of episode :560, avg score : 0.9
# # of episode :580, avg score : 1.25
# # of episode :600, avg score : 2.2
# # of episode :620, avg score : 3.3
# # of episode :640, avg score : 4.0
# # of episode :660, avg score : 2.8
# # of episode :680, avg score : 1.35
# # of episode :700, avg score : 6.4
# # of episode :720, avg score : 5.05
# # of episode :740, avg score : 3.65
# # of episode :760, avg score : 10.1
# # of episode :780, avg score : 6.8
# # of episode :800, avg score : 2.1
# # of episode :820, avg score : 4.3
# # of episode :840, avg score : 1.8
# # of episode :860, avg score : 4.7
# # of episode :880, avg score : 7.3
# # of episode :900, avg score : 1.1
# # of episode :920, avg score : 8.1
# # of episode :940, avg score : 3.85
# # of episode :960, avg score : 11.3
# # of episode :980, avg score : 6.3
# # of episode :1000, avg score : 2.05
# # of episode :1020, avg score : 4.7
# # of episode :1040, avg score : 10.55
# # of episode :1060, avg score : 8.8
# # of episode :1080, avg score : 6.45
# # of episode :1100, avg score : 3.0
# # of episode :1120, avg score : 18.3
# # of episode :1140, avg score : 11.05
# # of episode :1160, avg score : 2.0
# # of episode :1180, avg score : 1.9
# # of episode :1200, avg score : 1.85
# # of episode :1220, avg score : 9.1
# # of episode :1240, avg score : 19.5
# # of episode :1260, avg score : 13.4
# # of episode :1280, avg score : 7.5
# # of episode :1300, avg score : 4.85
# # of episode :1320, avg score : 8.75
# # of episode :1340, avg score : 8.6
# # of episode :1360, avg score : 13.85
# # of episode :1380, avg score : 11.75
# # of episode :1400, avg score : 7.15
# # of episode :1420, avg score : 12.2
# # of episode :1440, avg score : 8.15
# # of episode :1460, avg score : 13.25
# # of episode :1480, avg score : 10.15
# # of episode :1500, avg score : 23.85
# # of episode :1520, avg score : 8.65
# # of episode :1540, avg score : 11.5
# # of episode :1560, avg score : 7.45
# # of episode :1580, avg score : 21.0
# # of episode :1600, avg score : 8.55
# # of episode :1620, avg score : 12.15
# # of episode :1640, avg score : 17.75
# # of episode :1660, avg score : 8.05
# # of episode :1680, avg score : 5.1
# # of episode :1700, avg score : 17.85
# # of episode :1720, avg score : 15.25
# # of episode :1740, avg score : 6.55
# # of episode :1760, avg score : 18.65
# # of episode :1780, avg score : 25.0
# # of episode :1800, avg score : 5.55
# # of episode :1820, avg score : 21.15
# # of episode :1840, avg score : 9.6
# # of episode :1860, avg score : 10.0
# # of episode :1880, avg score : 11.4
# # of episode :1900, avg score : 9.9
# # of episode :1920, avg score : 9.55
# # of episode :1940, avg score : 14.45
# # of episode :1960, avg score : 12.45
# # of episode :1980, avg score : 11.0
# # of episode :2000, avg score : 9.95
# # of episode :2020, avg score : 14.0
# # of episode :2040, avg score : 13.15
# # of episode :2060, avg score : 14.05
# # of episode :2080, avg score : 13.7
# # of episode :2100, avg score : 10.0
# # of episode :2120, avg score : 10.15
# # of episode :2140, avg score : 25.0
# # of episode :2160, avg score : 10.8
# # of episode :2180, avg score : 25.0
# # of episode :2200, avg score : 6.55
# # of episode :2220, avg score : 14.25
# # of episode :2240, avg score : 14.15
# # of episode :2260, avg score : 25.0
# # of episode :2280, avg score : 4.8
# # of episode :2300, avg score : 8.7
# # of episode :2320, avg score : 25.0
# # of episode :2340, avg score : 25.0
# # of episode :2360, avg score : 25.0
# # of episode :2380, avg score : 20.35
# # of episode :2400, avg score : 15.1
# # of episode :2420, avg score : 25.0
# # of episode :2440, avg score : 22.45
# # of episode :2460, avg score : 11.8
# # of episode :2480, avg score : 12.2
# # of episode :2500, avg score : 18.5
# # of episode :2520, avg score : 9.2
# # of episode :2540, avg score : 12.5
# # of episode :2560, avg score : 4.75
# # of episode :2580, avg score : 18.75
# # of episode :2600, avg score : 25.0
# # of episode :2620, avg score : 16.6
# # of episode :2640, avg score : 19.1
# # of episode :2660, avg score : 25.0
# # of episode :2680, avg score : 15.15
# # of episode :2700, avg score : 22.05
# # of episode :2720, avg score : 16.8
# # of episode :2740, avg score : 19.45
# # of episode :2760, avg score : 22.65
# # of episode :2780, avg score : 24.55
# # of episode :2800, avg score : 24.4
# # of episode :2820, avg score : 13.75
# # of episode :2840, avg score : 19.7
# # of episode :2860, avg score : 19.45
# # of episode :2880, avg score : 25.0
# # of episode :2900, avg score : 14.9
# # of episode :2920, avg score : 9.65
# # of episode :2940, avg score : 23.25
# # of episode :2960, avg score : 16.95
# # of episode :2980, avg score : 11.8
# # of episode :3000, avg score : 25.0
# # of episode :3020, avg score : 13.9
# # of episode :3040, avg score : 23.8
# # of episode :3060, avg score : 25.0
# # of episode :3080, avg score : 24.2
# # of episode :3100, avg score : 19.85
# # of episode :3120, avg score : 16.6
# # of episode :3140, avg score : 25.0
# # of episode :3160, avg score : 25.0
# # of episode :3180, avg score : 24.05
# # of episode :3200, avg score : 16.65
# # of episode :3220, avg score : 14.2
# # of episode :3240, avg score : 24.0
# # of episode :3260, avg score : 12.2
# # of episode :3280, avg score : 12.25
# # of episode :3300, avg score : 11.45
# # of episode :3320, avg score : 13.15
# # of episode :3340, avg score : 23.0
# # of episode :3360, avg score : 25.0
# # of episode :3380, avg score : 9.3
# # of episode :3400, avg score : 25.0
# # of episode :3420, avg score : 21.05
# # of episode :3440, avg score : 19.5
# # of episode :3460, avg score : 25.0
# # of episode :3480, avg score : 25.0
# # of episode :3500, avg score : 25.0
# # of episode :3520, avg score : 18.65
# # of episode :3540, avg score : 17.2
# # of episode :3560, avg score : 25.0
# # of episode :3580, avg score : 25.0
# # of episode :3600, avg score : 19.15
# # of episode :3620, avg score : 18.2
# # of episode :3640, avg score : 25.0
# # of episode :3660, avg score : 15.3
# # of episode :3680, avg score : 25.0
# # of episode :3700, avg score : 25.0
# # of episode :3720, avg score : 20.0
# # of episode :3740, avg score : 19.85
# # of episode :3760, avg score : 16.85
# # of episode :3780, avg score : 18.25
# # of episode :3800, avg score : 25.0
# # of episode :3820, avg score : 25.0
# # of episode :3840, avg score : 24.15

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma = 0.98
class Policy(nn.Module):
    def __init__(self):
        super(Policy, self). __init__()
        self.data = []
        self.fc1 = nn. Linear(4, 128)
        self.fc2 = nn.Linear(128, 2)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.softmax(self.fc2(x), dim=0)
        return x

    def put_data(self, item):
        self.data.append(item)

    def train_net(self):
        R = 0
        self.optimizer.zero_grad()
        for r, prob in self.data[::-1]:
            R = r + gamma * R
            loss = -torch.log(prob) * R
            loss. backward()
        self.optimizer.step()
        self.data = []
def main() :
    env = gym.make('CartPole-v1')
    pi = Policy()
    score = 0.0
    print_interval = 20
    for n_epi in range (10000):
        s= env.reset()
        done = False
        while not done:
            prob = pi(torch.from_numpy(s).float())
            m = Categorical(prob)
            a = m.sample()
            s_prime, r, done, info = env.step(a.item())
            pi.put_data((r,prob[a]))
            s = s_prime
            score += r
        pi.train_net()
        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
        score = 0.0
    env.close()
if __name__ == '__main__' :
    main()
# Out:
# # of episode :20, avg score : 1.2
# # of episode :40, avg score : 1.75
# # of episode :60, avg score : 1.15
# # of episode :80, avg score : 1.05
# # of episode :100, avg score : 0.95
# # of episode :120, avg score : 3.2
# # of episode :140, avg score : 0.55
# # of episode :160, avg score : 0.7
# # of episode :180, avg score : 2.05
# # of episode :200, avg score : 1.65
# # of episode :220, avg score : 1.65
# # of episode :240, avg score : 1.2
# # of episode :260, avg score : 0.8
# # of episode :280, avg score : 0.75
# # of episode :300, avg score : 1.3
# # of episode :320, avg score : 0.9
# # of episode :340, avg score : 0.9
# # of episode :360, avg score : 1.75
# # of episode :380, avg score : 1.2
# # of episode :400, avg score : 1.75
# # of episode :420, avg score : 2.6
# # of episode :440, avg score : 1.15
# # of episode :460, avg score : 1.35
# # of episode :480, avg score : 2.25
# # of episode :500, avg score : 1.35
# # of episode :520, avg score : 2.25
# # of episode :540, avg score : 1.2
# # of episode :560, avg score : 2.55
# # of episode :580, avg score : 0.8
# # of episode :600, avg score : 1.5
# # of episode :620, avg score : 1.45
# # of episode :640, avg score : 2.15
# # of episode :660, avg score : 0.8
# # of episode :680, avg score : 4.2
# # of episode :700, avg score : 3.15
# # of episode :720, avg score : 5.0
# # of episode :740, avg score : 1.3
# # of episode :760, avg score : 1.1
# # of episode :780, avg score : 0.7
# # of episode :800, avg score : 2.15
# # of episode :820, avg score : 1.4
# # of episode :840, avg score : 0.85
# # of episode :860, avg score : 3.2
# # of episode :880, avg score : 8.65
# # of episode :900, avg score : 2.65
# # of episode :920, avg score : 0.7
# # of episode :940, avg score : 1.7
# # of episode :960, avg score : 1.1
# # of episode :980, avg score : 1.15
# # of episode :1000, avg score : 6.35
# # of episode :1020, avg score : 3.55
# # of episode :1040, avg score : 1.9
# # of episode :1060, avg score : 3.2
# # of episode :1080, avg score : 4.1
# # of episode :1100, avg score : 7.3
# # of episode :1120, avg score : 4.55
# # of episode :1140, avg score : 3.05
# # of episode :1160, avg score : 3.55
# # of episode :1180, avg score : 4.8
# # of episode :1200, avg score : 6.85
# # of episode :1220, avg score : 2.25
# # of episode :1240, avg score : 2.85
# # of episode :1260, avg score : 1.5
# # of episode :1280, avg score : 3.85
# # of episode :1300, avg score : 4.25
# # of episode :1320, avg score : 3.65
# # of episode :1340, avg score : 6.3
# # of episode :1360, avg score : 10.75
# # of episode :1380, avg score : 8.45
# # of episode :1400, avg score : 6.85
# # of episode :1420, avg score : 9.6
# # of episode :1440, avg score : 4.1
# # of episode :1460, avg score : 6.55
# # of episode :1480, avg score : 6.1
# # of episode :1500, avg score : 10.7
# # of episode :1520, avg score : 10.6
# # of episode :1540, avg score : 6.65
# # of episode :1560, avg score : 7.9
# # of episode :1580, avg score : 7.65
# # of episode :1600, avg score : 8.8
# # of episode :1620, avg score : 11.55
# # of episode :1640, avg score : 8.2
# # of episode :1660, avg score : 17.6
# # of episode :1680, avg score : 11.25
# # of episode :1700, avg score : 3.8
# # of episode :1720, avg score : 7.55
# # of episode :1740, avg score : 17.8
# # of episode :1760, avg score : 6.0
# # of episode :1780, avg score : 24.75
# # of episode :1800, avg score : 15.05
# # of episode :1820, avg score : 8.2
# # of episode :1840, avg score : 5.75
# # of episode :1860, avg score : 6.0
# # of episode :1880, avg score : 7.35
# # of episode :1900, avg score : 16.45
# # of episode :1920, avg score : 7.0
# # of episode :1940, avg score : 8.2
# # of episode :1960, avg score : 5.25
# # of episode :1980, avg score : 10.8
# # of episode :2000, avg score : 7.65
# # of episode :2020, avg score : 8.75
# # of episode :2040, avg score : 12.45
# # of episode :2060, avg score : 16.8
# # of episode :2080, avg score : 6.25
# # of episode :2100, avg score : 16.95
# # of episode :2120, avg score : 7.75
# # of episode :2140, avg score : 12.1
# # of episode :2160, avg score : 11.15
# # of episode :2180, avg score : 12.9
# # of episode :2200, avg score : 8.75
# # of episode :2220, avg score : 15.3
# # of episode :2240, avg score : 12.4
# # of episode :2260, avg score : 6.9
# # of episode :2280, avg score : 12.35
# # of episode :2300, avg score : 8.6
# # of episode :2320, avg score : 14.0
# # of episode :2340, avg score : 6.55
# # of episode :2360, avg score : 8.55
# # of episode :2380, avg score : 20.75
# # of episode :2400, avg score : 9.0
# # of episode :2420, avg score : 11.0
# # of episode :2440, avg score : 14.65
# # of episode :2460, avg score : 9.75
# # of episode :2480, avg score : 23.95
# # of episode :2500, avg score : 16.4
# # of episode :2520, avg score : 12.65
# # of episode :2540, avg score : 8.35
# # of episode :2560, avg score : 11.1
# # of episode :2580, avg score : 24.2
# # of episode :2600, avg score : 14.25
# # of episode :2620, avg score : 9.1
# # of episode :2640, avg score : 25.0
# # of episode :2660, avg score : 13.2
# # of episode :2680, avg score : 21.15
# # of episode :2700, avg score : 10.55
# # of episode :2720, avg score : 25.0
# # of episode :2740, avg score : 13.7
# # of episode :2760, avg score : 14.65
# # of episode :2780, avg score : 14.75
# # of episode :2800, avg score : 9.45
# # of episode :2820, avg score : 18.15
# # of episode :2840, avg score : 11.45
# # of episode :2860, avg score : 22.2
# # of episode :2880, avg score : 11.1
# # of episode :2900, avg score : 12.6
# # of episode :2920, avg score : 13.85
# # of episode :2940, avg score : 25.0
# # of episode :2960, avg score : 18.3
# # of episode :2980, avg score : 12.95
# # of episode :3000, avg score : 10.9
# # of episode :3020, avg score : 25.0
# # of episode :3040, avg score : 20.5
# # of episode :3060, avg score : 10.75
# # of episode :3080, avg score : 16.9
# # of episode :3100, avg score : 16.45
# # of episode :3120, avg score : 18.1
# # of episode :3140, avg score : 17.8
# # of episode :3160, avg score : 8.95
# # of episode :3180, avg score : 17.55
# # of episode :3200, avg score : 7.85
# # of episode :3220, avg score : 15.3
# # of episode :3240, avg score : 25.0
# # of episode :3260, avg score : 17.5
# # of episode :3280, avg score : 25.0
# # of episode :3300, avg score : 10.5
# # of episode :3320, avg score : 11.4
# # of episode :3340, avg score : 14.6
# # of episode :3360, avg score : 6.45
# # of episode :3380, avg score : 25.0
# # of episode :3400, avg score : 15.7
# # of episode :3420, avg score : 19.65
# # of episode :3440, avg score : 17.55
# # of episode :3460, avg score : 12.5
# # of episode :3480, avg score : 8.7
# # of episode :3500, avg score : 25.0
# # of episode :3520, avg score : 6.0
# # of episode :3540, avg score : 15.2
# # of episode :3560, avg score : 15.5
# # of episode :3580, avg score : 22.55
# # of episode :3600, avg score : 20.0
# # of episode :3620, avg score : 21.05
# # of episode :3640, avg score : 8.75
# # of episode :3660, avg score : 19.05
# # of episode :3680, avg score : 13.45
# # of episode :3700, avg score : 9.65
# # of episode :3720, avg score : 18.85
# # of episode :3740, avg score : 6.35
# # of episode :3760, avg score : 12.55
# # of episode :3780, avg score : 25.0
# # of episode :3800, avg score : 9.8
# # of episode :3820, avg score : 10.35
# # of episode :3840, avg score : 23.85
# # of episode :3860, avg score : 11.8
# # of episode :3880, avg score : 16.95
# # of episode :3900, avg score : 10.3
# # of episode :3920, avg score : 12.7
# # of episode :3940, avg score : 25.0
# # of episode :3960, avg score : 21.15
# # of episode :3980, avg score : 25.0
# # of episode :4000, avg score : 17.7
# # of episode :4020, avg score : 22.9
# # of episode :4040, avg score : 18.15
# # of episode :4060, avg score : 25.0
# # of episode :4080, avg score : 25.0
# # of episode :4100, avg score : 18.7
# # of episode :4120, avg score : 22.8
# # of episode :4140, avg score : 16.8
# # of episode :4160, avg score : 9.9
# # of episode :4180, avg score : 14.7
# # of episode :4200, avg score : 16.95
# # of episode :4220, avg score : 15.6
# # of episode :4240, avg score : 25.0
# # of episode :4260, avg score : 14.7
# # of episode :4280, avg score : 15.5
# # of episode :4300, avg score : 25.0
# # of episode :4320, avg score : 20.65
# # of episode :4340, avg score : 25.0
# # of episode :4360, avg score : 16.4
# # of episode :4380, avg score : 13.5
# # of episode :4400, avg score : 25.0
# # of episode :4420, avg score : 25.0
# # of episode :4440, avg score : 25.0
# # of episode :4460, avg score : 13.55
# # of episode :4480, avg score : 14.8
# # of episode :4500, avg score : 19.75
# # of episode :4520, avg score : 17.0
# # of episode :4540, avg score : 25.0
# # of episode :4560, avg score : 15.9
# # of episode :4580, avg score : 25.0
# # of episode :4600, avg score : 20.25
# # of episode :4620, avg score : 14.7
# # of episode :4640, avg score : 11.7
# # of episode :4660, avg score : 10.15
# # of episode :4680, avg score : 18.05
# # of episode :4700, avg score : 9.2
# # of episode :4720, avg score : 19.0
# # of episode :4740, avg score : 18.75
# # of episode :4760, avg score : 13.2
# # of episode :4780, avg score : 8.8
# # of episode :4800, avg score : 14.15
# # of episode :4820, avg score : 15.2
# # of episode :4840, avg score : 18.55
# # of episode :4860, avg score : 12.55
# # of episode :4880, avg score : 20.7
# # of episode :4900, avg score : 7.8
# # of episode :4920, avg score : 15.35
# # of episode :4940, avg score : 12.15
# # of episode :4960, avg score : 19.1
# # of episode :4980, avg score : 22.3
# # of episode :5000, avg score : 12.95
# # of episode :5020, avg score : 14.15
# # of episode :5040, avg score : 22.95
# # of episode :5060, avg score : 19.1
# # of episode :5080, avg score : 10.35
# # of episode :5100, avg score : 7.0
# # of episode :5120, avg score : 17.25
# # of episode :5140, avg score : 9.25
# # of episode :5160, avg score : 5.7
# # of episode :5180, avg score : 25.0
# # of episode :5200, avg score : 25.0
# # of episode :5220, avg score : 25.0
# # of episode :5240, avg score : 15.15
# # of episode :5260, avg score : 14.6
# # of episode :5280, avg score : 25.0
# # of episode :5300, avg score : 24.2
# # of episode :5320, avg score : 23.05
# # of episode :5340, avg score : 18.25
# # of episode :5360, avg score : 25.0
# # of episode :5380, avg score : 25.0
# # of episode :5400, avg score : 14.55
# # of episode :5420, avg score : 25.0
# # of episode :5440, avg score : 14.45
# # of episode :5460, avg score : 25.0
# # of episode :5480, avg score : 24.6
# # of episode :5500, avg score : 25.0
# # of episode :5520, avg score : 25.0
# # of episode :5540, avg score : 25.0
# # of episode :5560, avg score : 25.0
# # of episode :5580, avg score : 25.0
# # of episode :5600, avg score : 9.7
# # of episode :5620, avg score : 25.0
# # of episode :5640, avg score : 25.0
# # of episode :5660, avg score : 10.9
# # of episode :5680, avg score : 25.0
# # of episode :5700, avg score : 25.0
# # of episode :5720, avg score : 25.0
# # of episode :5740, avg score : 20.85
# # of episode :5760, avg score : 12.9
# # of episode :5780, avg score : 25.0
# # of episode :5800, avg score : 25.0
# # of episode :5820, avg score : 22.3
# # of episode :5840, avg score : 25.0
# # of episode :5860, avg score : 25.0
# # of episode :5880, avg score : 25.0
# # of episode :5900, avg score : 25.0
# # of episode :5920, avg score : 23.8
# # of episode :5940, avg score : 25.0
# # of episode :5960, avg score : 25.0
# # of episode :5980, avg score : 25.0
# # of episode :6000, avg score : 25.0
# # of episode :6020, avg score : 25.0
# # of episode :6040, avg score : 25.0
# # of episode :6060, avg score : 11.8
# # of episode :6080, avg score : 25.0
# # of episode :6100, avg score : 25.0
# # of episode :6120, avg score : 17.0
# # of episode :6140, avg score : 25.0
# # of episode :6160, avg score : 25.0
# # of episode :6180, avg score : 25.0
# # of episode :6200, avg score : 17.8
# # of episode :6220, avg score : 25.0
# # of episode :6240, avg score : 25.0
# # of episode :6260, avg score : 25.0
# # of episode :6280, avg score : 16.95
# # of episode :6300, avg score : 16.75
# # of episode :6320, avg score : 20.9
# # of episode :6340, avg score : 18.35
# # of episode :6360, avg score : 8.15
# # of episode :6380, avg score : 14.45
# # of episode :6400, avg score : 9.0
# # of episode :6420, avg score : 25.0
# # of episode :6440, avg score : 25.0
# # of episode :6460, avg score : 25.0
# # of episode :6480, avg score : 25.0
# # of episode :6500, avg score : 25.0
# # of episode :6520, avg score : 25.0
# # of episode :6540, avg score : 25.0
# # of episode :6560, avg score : 25.0
# # of episode :6580, avg score : 25.0
# # of episode :6600, avg score : 25.0
# # of episode :6620, avg score : 25.0
# # of episode :6640, avg score : 25.0
# # of episode :6660, avg score : 15.85
# # of episode :6680, avg score : 14.3
# # of episode :6700, avg score : 25.0
# # of episode :6720, avg score : 25.0
# # of episode :6740, avg score : 25.0
# # of episode :6760, avg score : 25.0
# # of episode :6780, avg score : 17.6
# # of episode :6800, avg score : 25.0
# # of episode :6820, avg score : 22.95
# # of episode :6840, avg score : 25.0
# # of episode :6860, avg score : 25.0
# # of episode :6880, avg score : 25.0
# # of episode :6900, avg score : 21.2
# # of episode :6920, avg score : 14.95
# # of episode :6940, avg score : 25.0
# # of episode :6960, avg score : 25.0
# # of episode :6980, avg score : 25.0
# # of episode :7000, avg score : 16.55
# # of episode :7020, avg score : 19.65
# # of episode :7040, avg score : 25.0
# # of episode :7060, avg score : 17.05
# # of episode :7080, avg score : 25.0
# # of episode :7100, avg score : 8.95
# # of episode :7120, avg score : 10.1
# # of episode :7140, avg score : 25.0
# # of episode :7160, avg score : 25.0
# # of episode :7180, avg score : 25.0
# # of episode :7200, avg score : 25.0
# # of episode :7220, avg score : 25.0
# # of episode :7240, avg score : 25.0
# # of episode :7260, avg score : 25.0
# # of episode :7280, avg score : 25.0
# # of episode :7300, avg score : 25.0
# # of episode :7320, avg score : 25.0
# # of episode :7340, avg score : 25.0
# # of episode :7360, avg score : 25.0
# # of episode :7380, avg score : 25.0
# # of episode :7400, avg score : 23.35
# # of episode :7420, avg score : 25.0
# # of episode :7440, avg score : 25.0
# # of episode :7460, avg score : 25.0
# # of episode :7480, avg score : 25.0
# # of episode :7500, avg score : 25.0
# # of episode :7520, avg score : 25.0
# # of episode :7540, avg score : 25.0
# # of episode :7560, avg score : 25.0
# # of episode :7580, avg score : 7.35
# # of episode :7600, avg score : 25.0
# # of episode :7620, avg score : 25.0
# # of episode :7640, avg score : 25.0
# # of episode :7660, avg score : 25.0
# # of episode :7680, avg score : 25.0
# # of episode :7700, avg score : 25.0
# # of episode :7720, avg score : 24.65
# # of episode :7740, avg score : 25.0
# # of episode :7760, avg score : 25.0
# # of episode :7780, avg score : 25.0
# # of episode :7800, avg score : 25.0
# # of episode :7820, avg score : 19.1
# # of episode :7840, avg score : 22.5
# # of episode :7860, avg score : 19.25
# # of episode :7880, avg score : 25.0
# # of episode :7900, avg score : 25.0
# # of episode :7920, avg score : 25.0
# # of episode :7940, avg score : 21.45
# # of episode :7960, avg score : 25.0
# # of episode :7980, avg score : 25.0
# # of episode :8000, avg score : 14.75
# # of episode :8020, avg score : 25.0
# # of episode :8040, avg score : 25.0
# # of episode :8060, avg score : 25.0
# # of episode :8080, avg score : 25.0
# # of episode :8100, avg score : 25.0
# # of episode :8120, avg score : 25.0
# # of episode :8140, avg score : 25.0
# # of episode :8160, avg score : 25.0
# # of episode :8180, avg score : 25.0
# # of episode :8200, avg score : 25.0
# # of episode :8220, avg score : 25.0
# # of episode :8240, avg score : 25.0
# # of episode :8260, avg score : 25.0
# # of episode :8280, avg score : 25.0
# # of episode :8300, avg score : 24.65
# # of episode :8320, avg score : 25.0
# # of episode :8340, avg score : 12.25
# # of episode :8360, avg score : 25.0
# # of episode :8380, avg score : 25.0
# # of episode :8400, avg score : 25.0
# # of episode :8420, avg score : 25.0
# # of episode :8440, avg score : 25.0
# # of episode :8460, avg score : 25.0
# # of episode :8480, avg score : 13.5
# # of episode :8500, avg score : 25.0
# # of episode :8520, avg score : 25.0
# # of episode :8540, avg score : 10.4
# # of episode :8560, avg score : 25.0
# # of episode :8580, avg score : 25.0
# # of episode :8600, avg score : 25.0
# # of episode :8620, avg score : 25.0
# # of episode :8640, avg score : 25.0
# # of episode :8660, avg score : 25.0
# # of episode :8680, avg score : 14.3
# # of episode :8700, avg score : 25.0
# # of episode :8720, avg score : 25.0
# # of episode :8740, avg score : 25.0
# # of episode :8760, avg score : 16.65
# # of episode :8780, avg score : 25.0
# # of episode :8800, avg score : 25.0
# # of episode :8820, avg score : 21.15
# # of episode :8840, avg score : 22.1
# # of episode :8860, avg score : 25.0
# # of episode :8880, avg score : 25.0
# # of episode :8900, avg score : 25.0
# # of episode :8920, avg score : 25.0
# # of episode :8940, avg score : 25.0
# # of episode :8960, avg score : 25.0
# # of episode :8980, avg score : 25.0
# # of episode :9000, avg score : 25.0
# # of episode :9020, avg score : 25.0
# # of episode :9040, avg score : 25.0
# # of episode :9060, avg score : 25.0
# # of episode :9080, avg score : 25.0
# # of episode :9100, avg score : 25.0
# # of episode :9120, avg score : 25.0
# # of episode :9140, avg score : 25.0
# # of episode :9160, avg score : 25.0
# # of episode :9180, avg score : 25.0
# # of episode :9200, avg score : 20.9
# # of episode :9220, avg score : 25.0
# # of episode :9240, avg score : 25.0
# # of episode :9260, avg score : 25.0
# # of episode :9280, avg score : 25.0
# # of episode :9300, avg score : 25.0
# # of episode :9320, avg score : 19.45
# # of episode :9340, avg score : 25.0
# # of episode :9360, avg score : 25.0
# # of episode :9380, avg score : 25.0
# # of episode :9400, avg score : 25.0
# # of episode :9420, avg score : 25.0
# # of episode :9440, avg score : 25.0
# # of episode :9460, avg score : 25.0
# # of episode :9480, avg score : 25.0
# # of episode :9500, avg score : 25.0
# # of episode :9520, avg score : 25.0
# # of episode :9540, avg score : 25.0
# # of episode :9560, avg score : 14.6
# # of episode :9580, avg score : 25.0
# # of episode :9600, avg score : 25.0
# # of episode :9620, avg score : 25.0
# # of episode :9640, avg score : 22.5
# # of episode :9660, avg score : 25.0
# # of episode :9680, avg score : 25.0
# # of episode :9700, avg score : 25.0
# # of episode :9720, avg score : 25.0
# # of episode :9740, avg score : 21.45
# # of episode :9760, avg score : 25.0
# # of episode :9780, avg score : 25.0
# # of episode :9800, avg score : 25.0
# # of episode :9820, avg score : 25.0
# # of episode :9840, avg score : 25.0
# # of episode :9860, avg score : 25.0
# # of episode :9880, avg score : 25.0
# # of episode :9900, avg score : 12.2
# # of episode :9920, avg score : 25.0
# # of episode :9940, avg score : 23.7
# # of episode :9960, avg score : 25.0
# # of episode :9980, avg score : 25.0

# %%
# CartPole 문제 #Actor-Critic(AC)

import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

#Hyperparameters
learning_rate = 0.0002
gamma = 0.98
n_rollout = 10

class ActorCritic(nn.Module):
    def __init__(self):
        super(ActorCritic, self). __init__()
        self.data = []

        self.fc1 = nn. Linear(4, 256)
        self.fc2 = nn.Linear(256, 2)
        self.fc_v = nn.Linear(256,1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self,x,softmax_dim=0):
      x = F.relu(self.fc1(x))
      x = self.fc_pi(x)
      prob = F.softmax(x,dim = softmax_dim)
      return prob

    def v(self, x):
        x = F.relu(self.fc1(x))
        v = self.fc_v(x)
        return v

    def put_data(self, transition):
        self.data.append(transition)

    def make_batch(self):
      s_lst, a_lst, r_lst, s_prime_lst, done_lst = [],[],[],[],[]

      for transition in self.data:
        s,a,r,s_prime,done = transition
        s_lst.append(s)
        a_lst.append([a])
        r_lst.append([r/100.0])
        s_prime_lst.append(s_prime)
        done_mask = 0.0 if done else 1.0
        done_lst.append([done_mask])

      s_batch, a_batch, r_batch, s_prime_batch, done_batch = torch.tensor(s_lst, dtype =torch.float), torch.tensor(a_lst),torch.tensor(r_lst, dtype =torch.float), torch.tensor(s_prime_lst, dtype =torch.float),torch.tensor(done_lst, dtype =torch.float)
      self.data = []
      return s_batch, a_batch, r_batch, s_prime_batch, done_batch

    def train_net(self):
        s,a,r,s_prime,done = self.make_batch()
        td_target = r+gamma*self.v(s_prime)*done
        delta = td_target - self.v(s)

        pi = self.pi(s,softmax_dim =1)
        pi_a = pi.gather(1,a)
        loss = -torch.log(pi_a) * delta.detach() + F.smooth_1l_loss(self.v(s),td_target.detach())

        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()

def main() :
    env = gym.make('CartPole-v1')
    pi = ActorCritic()
    score = 0.0
    print_interval = 20

    for n_epi in range (10000):
        s= env.reset()
        done = False
        while not done:
          for t in range(n_rollout):
              prob = model.pi(torch.from_numpy(s).float())
              m = Categorical(prob)
              a = m.sample().item()
              s_prime, r, done, truncated, info = env.step(a)
              model.put_data((s,a,r,s_prime,done))
              s = s_prime
              score += r
              if done :
                break
          model.train_net()

        if n_epi%print_interval==0 and n_epi!=0:
            print("# of episode :{}, avg score : {}".format(n_epi, score/print_interval))
        score = 0.0
    env.close()
if __name__ == '__main__' :
    main()
