# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 12370, done.
# remote: Counting objects: 100% (1644/1644), done.
# remote: Compressing objects: 100% (1056/1056), done.
# remote: Total 12370 (delta 983), reused 1026 (delta 579), pack-reused 10726
# Receiving objects: 100% (12370/12370), 7.69 MiB | 17.08 MiB/s, done.
# Resolving deltas: 100% (8132/8132), done.

# %%
# !pip install ipynb-py-convert
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ipynb-py-convert: filename=ipynb_py_convert-0.4.6-py3-none-any.whl size=4623 sha256=cac27bdea1cc0291a4b4d763518a1c65adac9ae57add66ff218cbf504e62e317
#   Stored in directory: /root/.cache/pip/wheels/69/a2/b7/2816fda86a647adbe8c4e7b7f4cc72cdc37720ad11b1611af5
# Successfully built ipynb-py-convert
# ...

# %%
#ipynb파일로 변경
# !ipynb-py-convert ./ultralytics/setup.py ./ultralytics/setup.ipynb

# %%
# !ipynb-py-convert ./ultralytics/setup.py ./ultralytics/setup3.ipynb

# %%
# !pip install nbconvert

# %%
# py파일로 변경
# !jupyter nbconvert --to script ./ultralytics/setup3.ipynb
# Out:
# [NbConvertApp] Converting notebook ./ultralytics/setup3.ipynb to script
# [NbConvertApp] Writing 3158 bytes to ultralytics/setup3.py

# %%
#전체 폴더 py파일로 변경
#!jupyter nbconvert ./ultralytics/*.ipynb --to script
