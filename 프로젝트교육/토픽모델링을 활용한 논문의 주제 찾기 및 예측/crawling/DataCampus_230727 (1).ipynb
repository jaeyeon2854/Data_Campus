# %%
import os, re

# %%
import csv, os

# %%
def opencsv(filename):
    f = open(filename, 'r')
    reader = csv.reader(f)
    output = []
    for i in reader:
        output.append(i)
    f.close()
    return output

# %%
def writecsv(filename, the_list):
    with open(filename, 'w', newline = '') as f:
        a = csv.writer(f, delimiter = ',')
        a.writerows(the_list)

# %%
import usecsv

# %%
os.getcwd()
# Out:
# 'C:\\Users\\lovel\\Documents'

# %%
a = [['국어', '영어', '수학'],[99, 88, 77]]

# %%
usecsv.writecsv('test11.csv',a)

# %% [markdown]
# ### 웹 크롤링

# %%
# !pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os, re, usecsv

# %% [markdown]
# ### 웹 크롤링 하기 위해서 새로운 모듈

# %%
import requests

# %%
import urllib.request as ur

# %%
from bs4 import BeautifulSoup as bs

# %%
url = 'http://quotes.toscrape.com'

# %%
urllib.request.urlopen('URL주소')

# %%
html = ur.urlopen(url)

# %%
html

# %%
print(html)

# %%
html.read()[:100]
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n   '

# %%
html.read()[:100]
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n   '

# %%
soup = bs(html.read(), 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
type(html)
# Out:
# http.client.HTTPResponse

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#soup = bs(ur.urlopen(URL주소).read(), 'html.parser')

# %%
<HTML>
<head>
    <title> 페이지 제목 </title>
</head>
<body>
    <h1> 글 제목 </h1>
    <p> 글 본문 </p>
</body>
</HTML>
# Out:
#   Cell In[30], line 1
#     <HTML>
#     ^
# SyntaxError: invalid syntax

# %%
#find_all

# %%
soup.find_all('span')
# Out:
# [<span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>,
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>,
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>,
#  <span>by <small class="author" itemprop="author">J.K. Rowling</small>
#  <a href="/author/J-K-Rowling">(about)</a>
#  </span>,
#  <span class="text" itemprop="text">“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”</span>,
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>,
# ...

# %%
quote = soup.find_all('span')

# %%
quote[0]
# Out:
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>

# %%
quote[0].text
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
#soup.find_all('span')
soupa = soup.find_all('div', {"class" : "quote"})

# %%
soupa[0]
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>

# %%
soupb = soupa[0].text

# %%
print(soupb)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world

# %%
soupb
# Out:
# '\n“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”\nby Albert Einstein\n(about)\n\n\n            Tags:\n            \nchange\ndeep-thoughts\nthinking\nworld\n\n'

# %%
for i in soup.find_all('div', {"class" : "quote"}):
    print(i.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
#
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# by J.K. Rowling
# (about)
#
#
#             Tags:
#
# abilities
# choices
#
#
#
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# by Albert Einstein
# (about)
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
#
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# by Jane Austen
# (about)
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
#
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# by Marilyn Monroe
# (about)
#
#
# ...

# %% [markdown]
# ### 이제 작업할 내용은 새로운 시작입니다
# ### 따라오시면 됩니다

# %%
#input = text파일 (10개 ~ 30개)
#code = *.ipynb 파일 또는 *.py 코드
#output = wordcloud image & topic modeling result
#*.html 파일로 예쁘게 작업한 결과를 시각화 시키는 것까지 생각 중

# %%
import os, re

# %%
import urllib.request as ur

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
os.getcwd()
# Out:
# 'C:\\Users\\lovel\\Documents'

# %%
news = 'https://news.daum.net/'

# %%
news_html = ur.urlopen(news)
soup = bs(news_html.read(), 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/3ccc7b5/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/3ccc7b5/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
#머리기사 제목 추출하기

# %%
 soup.find_all('div', {"class" : "item_issue"})[0]
# Out:
# <div class="item_issue" data-tiara-layer="headline1">
# <a class="wrap_thumb" data-tiara-custom="contentUniqueKey=hamny-20230727094753023&amp;clusterId=5009334,5560246,5590543,5150097&amp;clusterTitle=공연전시,연극/뮤지컬,[언론사픽] 주요뉴스,문화&amp;keywordType=INTEREST,INTEREST,NONE,NONE" data-tiara-id="20230727094753023" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20230727094753023">
# <img '소시민의="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S96x60ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202307%2F27%2FNEWS1%2F20230727094755220lsgz.gif&amp;scode=media" 꿈…연극="" 내집마련의="" 잃어버린="" 전세사기에="" 칠거지악'"=""/>
# </a>
# <div class="cont_thumb">
# <span class="info_thumb">
# <span class="logo_cp">
# <img alt="뉴스1" class="thumb_g" onerror="this.style.display='none';" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_news1.gif"/>
# </span>
# <span class="txt_category">문화</span>
# </span>
# <strong class="tit_g">
# ...

# %%
soupa.text
# Out:
# "\n\n\n\n\n\n\n\n\n문화\n\n\n\n                                    전세사기에 잃어버린 내집마련의 꿈…연극 '소시민의 칠거지악'\n                                \n\n\n"

# %%
for i in soup.find_all('div', {"class":"item_issue"}):
    print(i.text)
# Out:
# 문화
#
#
#
#                                     전세사기에 잃어버린 내집마련의 꿈…연극 '소시민의 칠거지악'
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     ‘여름배추 90% 생산’ 강원… 작물 20%서 잎 썩어가는 ‘무름병’ 초비상
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     칼부림 학생 말린 교사에 책임 물은 부모…“그 아이, 누가 키웠습니까?” [긴급점검-교사들의 호소③]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 경제
#
#
#
#                                     ‘뜨거워지는 바닷물'.."어민들만 가슴 '철렁'한게 아니었네"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 정치
#
#
#
#                                     "장모님 댁에 고속도로 하나 놔드려야겠어요" vs "尹 탄핵?"[박영환의 시사1번지]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     오송 참사 시민대책위 "진상조사, 유족·시민단체 참여해야"
#
#
#
#
#
#
#
#
#
#
#
#
#
# 경제
#
#
#
#                                     여름휴가 가서 호텔 30만 원씩 써도 “제주는 아니”.. 서울·내륙으로 빠져,  왜?
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     대만발 우편물 36개, 검사 결과 '이상 없음'
#
#
#
#
#
#
#
#
#
#
#
#
#
# 정치
#
#
#
#                                     기초자치단체 부활 근거법 국회서 제동
#
#
#
#
#
# ...

# %%
#<a href = "링크할 URL 주소">하이퍼링크 텍스트<a>

# %%
soup.find_all('a')
# Out:
# [<a href="#mainContent">본문 바로가기</a>,
#  <a href="#gnbContent">메뉴 바로가기</a>,
#  <a class="link_daum" data-tiara-layer="gnb default logo" href="https://www.daum.net/">
#  <img alt="Daum" class="logo_daum" height="18" src="//t1.daumcdn.net/media/common/newsview_2021/pc/rtn/logo_daum.png" width="44"/>
#  </a>,
#  <a data-tiara-layer="GNB service news" href="https://news.daum.net/" id="kakaoServiceLogo">
#  <span class="ir_wa">뉴스</span>
#  </a>,
#  <a class="link_services" data-tiara-layer="enter" href="https://entertain.daum.net">연예</a>,
#  <a class="link_services" data-tiara-layer="sports" href="https://sports.daum.net">스포츠</a>,
#  <a class="link_gnb" data-tiara-layer="home" href="/"><span class="txt_gnb">홈</span></a>,
#  <a class="link_gnb" data-tiara-layer="society" href="/society"><span class="txt_gnb">사회</span></a>,
#  <a class="link_gnb" data-tiara-layer="politics" href="/politics"><span class="txt_gnb">정치</span></a>,
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="#mainContent">본문 바로가기</a>,
#  <a href="#gnbContent">메뉴 바로가기</a>,
#  <a class="link_daum" data-tiara-layer="gnb default logo" href="https://www.daum.net/">
#  <img alt="Daum" class="logo_daum" height="18" src="//t1.daumcdn.net/media/common/newsview_2021/pc/rtn/logo_daum.png" width="44"/>
#  </a>,
#  <a data-tiara-layer="GNB service news" href="https://news.daum.net/" id="kakaoServiceLogo">
#  <span class="ir_wa">뉴스</span>
#  </a>,
#  <a class="link_services" data-tiara-layer="enter" href="https://entertain.daum.net">연예</a>,
#  <a class="link_services" data-tiara-layer="sports" href="https://sports.daum.net">스포츠</a>,
#  <a class="link_gnb" data-tiara-layer="home" href="/"><span class="txt_gnb">홈</span></a>,
#  <a class="link_gnb" data-tiara-layer="society" href="/society"><span class="txt_gnb">사회</span></a>,
#  <a class="link_gnb" data-tiara-layer="politics" href="/politics"><span class="txt_gnb">정치</span></a>,
# ...

# %%
soup.find_all('a')[5]
# Out:
# <a class="link_services" data-tiara-layer="sports" href="https://sports.daum.net">스포츠</a>

# %%
#a 라는 태그에서 하이퍼링크의 주소값이 저장된 href 속성값을 가져오기로 한다
#이 태그를 저장한 객체 a가 있을 때 그 안의 특정한 속성값을 찾기 위해서는 get을 사용한다

# %%
for i in soup.find_all('a'):
    i.get('href')
# Out:
# #mainContent
# #gnbContent
# https://www.daum.net/
# https://news.daum.net/
# https://entertain.daum.net
# https://sports.daum.net
# /
# /society
# /politics
# /economic
# /foreign
# /culture
# /digital
# /series/
# /photo
# https://focus.daum.net/ch/news/factcheck
# https://v.daum.net/v/20230727094753023
# https://v.daum.net/v/20230727094753023
# https://v.daum.net/v/20230727115140303
# https://v.daum.net/v/20230727120140797
# https://v.daum.net/v/20230727120140797
# https://v.daum.net/v/20230727114602094
# https://v.daum.net/v/20230727114602094
# https://v.daum.net/v/20230727121901279
# https://v.daum.net/v/20230727121901279
# https://v.daum.net/v/20230727133434691
# https://v.daum.net/v/20230727133434691
# https://v.daum.net/v/20230727112613978
# https://v.daum.net/v/20230727112613978
# https://v.daum.net/v/20230727133253644
# https://v.daum.net/v/20230727133253644
# https://v.daum.net/v/20230727133129589
# https://v.daum.net/v/20230727133129589
# ...

# %%
aaa = []

for i in soup.find_all('a'):
    
    aaa.append(i.get('href'))

# %%
aaa
# Out:
# ['#mainContent',
#  '#gnbContent',
#  'https://www.daum.net/',
#  'https://news.daum.net/',
#  'https://entertain.daum.net',
#  'https://sports.daum.net',
#  '/',
#  '/society',
#  '/politics',
#  '/economic',
#  '/foreign',
#  '/culture',
#  '/digital',
#  '/series/',
#  '/photo',
#  'https://focus.daum.net/ch/news/factcheck',
#  'https://v.daum.net/v/20230727094753023',
#  'https://v.daum.net/v/20230727094753023',
#  'https://v.daum.net/v/20230727115140303',
#  'https://v.daum.net/v/20230727120140797',
#  'https://v.daum.net/v/20230727120140797',
#  'https://v.daum.net/v/20230727114602094',
#  'https://v.daum.net/v/20230727114602094',
#  'https://v.daum.net/v/20230727121901279',
#  'https://v.daum.net/v/20230727121901279',
#  'https://v.daum.net/v/20230727133434691',
#  'https://v.daum.net/v/20230727133434691',
#  'https://v.daum.net/v/20230727112613978',
#  'https://v.daum.net/v/20230727112613978',
#  'https://v.daum.net/v/20230727133253644',
# ...

# %%
for i in soup.find_all('a'):
    
    print(i.get('href'))
# Out:
# #mainContent
# #gnbContent
# https://www.daum.net/
# https://news.daum.net/
# https://entertain.daum.net
# https://sports.daum.net
# /
# /society
# /politics
# /economic
# /foreign
# /culture
# /digital
# /series/
# /photo
# https://focus.daum.net/ch/news/factcheck
# https://v.daum.net/v/20230727094753023
# https://v.daum.net/v/20230727094753023
# https://v.daum.net/v/20230727115140303
# https://v.daum.net/v/20230727120140797
# https://v.daum.net/v/20230727120140797
# https://v.daum.net/v/20230727114602094
# https://v.daum.net/v/20230727114602094
# https://v.daum.net/v/20230727121901279
# https://v.daum.net/v/20230727121901279
# https://v.daum.net/v/20230727133434691
# https://v.daum.net/v/20230727133434691
# https://v.daum.net/v/20230727112613978
# https://v.daum.net/v/20230727112613978
# https://v.daum.net/v/20230727133253644
# https://v.daum.net/v/20230727133253644
# https://v.daum.net/v/20230727133129589
# https://v.daum.net/v/20230727133129589
# ...

# %%
for i in soup.find_all('div', {"class":"item_issue"}):
    print(i.find_all('a')[0].get('href'))
# Out:
# https://v.daum.net/v/20230727094753023
# https://v.daum.net/v/20230727115140303
# https://v.daum.net/v/20230727120140797
# https://v.daum.net/v/20230727114602094
# https://v.daum.net/v/20230727121901279
# https://v.daum.net/v/20230727133434691
# https://v.daum.net/v/20230727112613978
# https://v.daum.net/v/20230727133253644
# https://v.daum.net/v/20230727133129589
# https://v.daum.net/v/20230727131005091
# https://v.daum.net/v/20230727130953084
# https://v.daum.net/v/20230727131921224
# https://v.daum.net/v/20230727130521997
# https://v.daum.net/v/20230727132212286
# https://v.daum.net/v/20230727132759475
# https://v.daum.net/v/20230727120003584
# https://v.daum.net/v/20230727110501810
# https://v.daum.net/v/20230727132610420
# https://v.daum.net/v/20230727122102308
# https://v.daum.net/v/20230727131314137

# %%
bbb = soup.find_all('div', {"class":"item_issue"})
len(bbb)
# Out:
# 20

# %%
#list[0]으로 지정되어야 하는 이유

# %%
#find_all로 찾은 <a> 태그 모음 = [<a> 태그 1-1, <a> 태그 1-2, ...] ... [<a> 태그 n-1, ...]

# %%
newspaper = soup.find_all('div', {"class" : "item_issue"})

# %%
newspaper
# Out:
# [<div class="item_issue" data-tiara-layer="headline1">
#  <a class="wrap_thumb" data-tiara-custom="contentUniqueKey=hamny-20230727094753023&amp;clusterId=5009334,5560246,5590543,5150097&amp;clusterTitle=공연전시,연극/뮤지컬,[언론사픽] 주요뉴스,문화&amp;keywordType=INTEREST,INTEREST,NONE,NONE" data-tiara-id="20230727094753023" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20230727094753023">
#  <img '소시민의="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S96x60ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202307%2F27%2FNEWS1%2F20230727094755220lsgz.gif&amp;scode=media" 꿈…연극="" 내집마련의="" 잃어버린="" 전세사기에="" 칠거지악'"=""/>
#  </a>
#  <div class="cont_thumb">
#  <span class="info_thumb">
#  <span class="logo_cp">
#  <img alt="뉴스1" class="thumb_g" onerror="this.style.display='none';" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_news1.gif"/>
#  </span>
#  <span class="txt_category">문화</span>
#  </span>
#  <strong class="tit_g">
# ...

# %%
for i in newspaper:
    print(i.text, '\n')
# Out:
# 문화
#
#
#
#                                     전세사기에 잃어버린 내집마련의 꿈…연극 '소시민의 칠거지악'
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     ‘여름배추 90% 생산’ 강원… 작물 20%서 잎 썩어가는 ‘무름병’ 초비상
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     칼부림 학생 말린 교사에 책임 물은 부모…“그 아이, 누가 키웠습니까?” [긴급점검-교사들의 호소③]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 경제
#
#
#
#                                     ‘뜨거워지는 바닷물'.."어민들만 가슴 '철렁'한게 아니었네"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 정치
#
#
#
#                                     "장모님 댁에 고속도로 하나 놔드려야겠어요" vs "尹 탄핵?"[박영환의 시사1번지]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     오송 참사 시민대책위 "진상조사, 유족·시민단체 참여해야"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 경제
#
#
#
#                                     여름휴가 가서 호텔 30만 원씩 써도 “제주는 아니”.. 서울·내륙으로 빠져,  왜?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     대만발 우편물 36개, 검사 결과 '이상 없음'
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 정치
#
#
#
# ...

# %%
#for i in soup.find_all('div', {"class":"item_issue"}):
#    print(i.find_all('a')[0].get('href'))

ur.urlopen(i.find_all('a')[0].get('href')).read()
# Out:
# b'<!doctype html>\n<html class="os_window"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no"> \n  <meta name="format-detection" content="telephone=no"> \n  <meta name="referrer" content="unsafe-url"> \n  <title>\xec\x9d\xbc\xeb\xb3\xb8\xec\x9d\x98 \xeb\xaf\xb8\xec\xb9\x9c \xec\x97\x94\xec\xa0\x80, \xec\x9a\xb0\xeb\xa6\xac \xea\xb8\x88\xeb\xa6\xac\xeb\x8a\x94 \xec\x95\x88 \xeb\x82\xb4\xeb\xa6\xac\xeb\x82\x98?[\xea\xb2\xbd\xed\x96\xa5\xec\x8b\x9c\xec\x86\x8c]</title> \n  <link rel="shortcut icon" href="//t1.daumcdn.net/top/favicon.ico"> \n  <meta property="mccp:docId" content="Blle0TfOy7"> \n  <meta property="og:site_name" content="\xec\x96\xb8\xeb\xa1\xa0\xec\x82\xac \xeb\xb7\xb0"> \n  <meta property="og:title" content="\xec\x9d\xbc\xeb\xb3\xb8\xec\x9d\x98 \xeb\xaf\xb8\xec\xb9\x9c \xec\x97\x94\xec\xa0\x80, \xec\x9a
# ...

# %%
soupc = bs(ur.urlopen(i.find_all('a')[0].get('href')).read(), 'html.parser')

# %%
soupc
# Out:
# <!DOCTYPE html>
#
# <html class="os_window">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>일본의 미친 엔저, 우리 금리는 안 내리나?[경향시소]</title>
# <link href="//t1.daumcdn.net/top/favicon.ico" rel="shortcut icon"/>
# <meta content="Blle0TfOy7" property="mccp:docId"/>
# <meta content="언론사 뷰" property="og:site_name"/>
# <meta content="일본의 미친 엔저, 우리 금리는 안 내리나?[경향시소]" property="og:title"/>
# <meta content="20230727131314" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="경향신문" property="og:article:author"/>
# <meta content="https://v.daum.net/v/20230727131314137" property="og:url"/>
# ...

# %%
bbb = []

for j in soupc.find_all('p'):
    bbb.append(j.text)

# %%
bbb
# Out:
# ['이 글자크기로 변경됩니다.',
#  '(예시) 가장 빠른 뉴스가 있고 다양한 정보, 쌍방향 소통이 숨쉬는 다음뉴스를 만나보세요. 다음뉴스는 국내외 주요이슈와 실시간 속보, 문화생활 및 다양한 분야의 뉴스를 입체적으로 전달하고 있습니다.',
#  '지나쳐 보인다 싶은 ‘제로 금리’와 무제한 양적 완화를 근간으로 하는 아베노믹스 정책이 결국 효과를 내는 것 아니냐는 설명이 힘을 얻고 있습니다. 일본의 경제가 살아나고 있다는 신호들이 여기저기서 나타나고 있습니다.',
#  '경향신문의 유튜브채널 ‘이런 경향’의 뉴스 해설 콘텐츠 ‘경향시소(시사 소믈리에)’에서는 AI 기반 자동 투자 업체 핀테크기업 프리즘의 홍춘욱 대표로부터 일본 경제의 역사와 전망에 대해 들어봤습니다.',
#  '',
#  '일본은 강하게 유지하고 있는 저금리와 엔저 정책을 발판 삼아 기업의 실적이 나아지고 있습니다. 한동안 잠잠했던 물가도 조금씩 오르고 있는 상황입니다. 주식과 부동산 등 자산 시장도 회복 조짐을 보입니다.',
#  '홍춘욱 대표에 따르면 일본의 엔저 정책은 20년 넘게 이어지고 있습니다. 드디어 잃어버린 10년이 끝났다 싶었는데 911 테러가 벌어지면서 일본 경제가 또 한 번 휘청였고, 살아난다 싶던 2008년 세계적 금융위기가 닥치면서 또 한 번 흔들립니다. 2011년에는 동북부 대지진도 발생했고요.',
#  '이후 제로금리 정책을 지독할만큼 10년 넘게 유지한 끝에 경기 회복 가능성이 보이는 상황입니다.',
#  '그렇다면 우리나라는 어떻게 해야 할까요. 일본처럼 저금리 정책을 써야 할까요?',
#  '홍 대표는 “경제 혁신 능력에 있어서 여전히 OECD 국가 중 최상위권”이라고 설명합니다. 저금리의 도박을 할 이유가 적다는 뜻입니다. 홍 대표는 “일본은 이대로 가다가는 끝장이다라는 공포 속에서 정책을 추진했지만 우리나라는 다르다”고 말합니다.',
# ...

# %%
import os, codecs, re, datetime, requests
import urllib.request as ur
from bs4 import BeautifulSoup as bs
os.chdir(r'C:\Users\lovel\Documents\kimmi')
url = 'https://news.daum.net/'
f = open(str(datetime.date.today()) + 'articles.txt', 'w')
soup = bs(ur.urlopen(url).read(), 'html.parser')

for i in soup.find_all('div',{"class" : "item_issue"}):
    try:
        f.write(i.text+'\n')
        f.write(i.find_all('a')[0].get('href') + '\n')
        soup2 = bs(ur.urlopen(i.find_all('a')[0].get('href')).read(), 'html.parser')
        for j in soup2.find_all('p'):
            f.write(j.text)
    except:
        pass
f.close()

# %%
# !pip install pyinstaller
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/1.3 MB ? eta -:--:--
#      ---                                      0.1/1.3 MB 3.3 MB/s eta 0:00:01
#      -------                                  0.2/1.3 MB 2.8 MB/s eta 0:00:01
#      -----------                              0.4/1.3 MB 2.8 MB/s eta 0:00:01
#      ----------------                         0.5/1.3 MB 2.9 MB/s eta 0:00:01
#      ---------------------                    0.7/1.3 MB 3.0 MB/s eta 0:00:01
#      ---------------------------              0.9/1.3 MB 3.2 MB/s eta 0:00:01
#      ----------------------------------       1.1/1.3 MB 3.5 MB/s eta 0:00:01
#      ---------------------------------------  1.3/1.3 MB 3.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 3.4 MB/s eta 0:00:00
# ...
#                                               0.0/274.3 kB ? eta -:--:--
# ...

# %%
os.getcwd()
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'article_collector.py',
#  'data',
#  'DTM_semu.ipynb',
#  'LDA_M.ipynb',
#  'wordcloud_mi.ipynb']

# %%
pyinstaller article_collector.py
# Out:
#   Cell In[141], line 1
#     pyinstaller article_collector.py
#                 ^
# SyntaxError: invalid syntax

# %%
pyinstaller article_collector.py
# Out:
#   Cell In[142], line 1
#     pyinstaller article_collector.py
#                 ^
# SyntaxError: invalid syntax
