# %%
import csv, os

def opencsv(filename):
    f = open(filename, 'r')
    reader = csv.reader(f)
    output = []
    for i in reader:
        output.append(i)
    f.close()
    return output

def writecsv(filename, the_list):
    with open(filename, 'w', newline = '') as f:
        a = csv.writer(f, delimiter = ',')
        a.writerows(the_list)

# %%
# !pip install beautifulsoup4

# %%
import requests
import urllib.request as ur
from bs4 import BeautifulSoup as bs

# %%
news = 'https://news.daum.net/'

# %%
news_html = ur.urlopen(news)
soup = bs(news_html.read(), 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/3ccc7b5/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/3ccc7b5/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
#머리기사 제목 추출하기
maintitle = soup.find_all('div', {"class" : "item_issue"})[0]

# %%
maintitle.text
# Out:
# '\n\n\n\n\n\n\n\n\n경제\n\n\n\n                                    “소주‧맥주 가격 1000원 시대?”…주류업계 마케팅 방향 바뀌나\n                                \n\n\n'

# %%
for i in soup.find_all('div', {"class":"item_issue"}):
    print(i.text)
# Out:
# 경제
#
#
#
#                                     “소주‧맥주 가격 1000원 시대?”…주류업계 마케팅 방향 바뀌나
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     감사원, 방통위, 경찰까지···MBC 대주주 방문진 전방위 압박하는 정부
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     “내가 낸 세금으로 먹고살잖아” 폭언·폭행에 피멍 드는 공무원들
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     [ET뷰]대학기술지주회사 투자회사 1500개 넘어...운영체제 혁신 필요
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     [스페셜리포트]연합형 기술지주회사, 지자체·대학 협력 기반 되려면
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     "들개 떼에 호신용품까지"...검단신도시 '집중 출몰' 이유는?
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     '양식장 떼죽음' 116억 악몽…펄펄 끓는 부산~전남 앞바다 비상
#
#
#
#
#
#
#
#
#
#
#
# 경기일보
#
# 문화
#
#
#
#                                     폭염경보... 붐비는 '무료 급식소'  [포토뉴스]
#
#
#
#
#
#
#
#
#
#
#
# 경기일보
#
# 사회
#
#
#
#                                     수도권 보훈대상자, 철도운임 무임 지원 대상 확대
#
#
#
#
#
#
#
#
#
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="#mainContent">본문 바로가기</a>,
#  <a href="#gnbContent">메뉴 바로가기</a>,
#  <a class="link_daum" data-tiara-layer="gnb default logo" href="https://www.daum.net/">
#  <img alt="Daum" class="logo_daum" height="18" src="//t1.daumcdn.net/media/common/newsview_2021/pc/rtn/logo_daum.png" width="44"/>
#  </a>,
#  <a data-tiara-layer="GNB service news" href="https://news.daum.net/" id="kakaoServiceLogo">
#  <span class="ir_wa">뉴스</span>
#  </a>,
#  <a class="link_services" data-tiara-layer="enter" href="https://entertain.daum.net">연예</a>,
#  <a class="link_services" data-tiara-layer="sports" href="https://sports.daum.net">스포츠</a>,
#  <a class="link_gnb" data-tiara-layer="home" href="/"><span class="txt_gnb">홈</span></a>,
#  <a class="link_gnb" data-tiara-layer="society" href="/society"><span class="txt_gnb">사회</span></a>,
#  <a class="link_gnb" data-tiara-layer="politics" href="/politics"><span class="txt_gnb">정치</span></a>,
# ...

# %%
soup.find_all('a')[5]
# Out:
# <a class="link_services" data-tiara-layer="sports" href="https://sports.daum.net">스포츠</a>

# %%
for i in soup.find_all('a'):
    i.get('href')

# %%
linklist = []

for i in soup.find_all('a'):

    linklist.append(i.get('href'))

# %%
linklist
# Out:
# ['#mainContent',
#  '#gnbContent',
#  'https://www.daum.net/',
#  'https://news.daum.net/',
#  'https://entertain.daum.net',
#  'https://sports.daum.net',
#  '/',
#  '/society',
#  '/politics',
#  '/economic',
#  '/foreign',
#  '/culture',
#  '/digital',
#  '/series/',
#  '/photo',
#  'https://focus.daum.net/ch/news/factcheck',
#  'https://v.daum.net/v/20230802143727119',
#  'https://v.daum.net/v/20230802143727119',
#  'https://v.daum.net/v/20230802165131730',
#  'https://v.daum.net/v/20230802165131730',
#  'https://v.daum.net/v/20230802165849024',
#  'https://v.daum.net/v/20230802165849024',
#  'https://v.daum.net/v/20230802150015227',
#  'https://v.daum.net/v/20230802150015227',
#  'https://v.daum.net/v/20230802170112132',
#  'https://v.daum.net/v/20230802170112132',
#  'https://v.daum.net/v/20230802161751447',
#  'https://v.daum.net/v/20230802161751447',
#  'https://v.daum.net/v/20230802170037100',
#  'https://v.daum.net/v/20230802170037100',
# ...

# %%
for i in soup.find_all('a'):

    print(i.get('href'))
# Out:
# #mainContent
# #gnbContent
# https://www.daum.net/
# https://news.daum.net/
# https://entertain.daum.net
# https://sports.daum.net
# /
# /society
# /politics
# /economic
# /foreign
# /culture
# /digital
# /series/
# /photo
# https://focus.daum.net/ch/news/factcheck
# https://v.daum.net/v/20230802143727119
# https://v.daum.net/v/20230802143727119
# https://v.daum.net/v/20230802165131730
# https://v.daum.net/v/20230802165131730
# https://v.daum.net/v/20230802165849024
# https://v.daum.net/v/20230802165849024
# https://v.daum.net/v/20230802150015227
# https://v.daum.net/v/20230802150015227
# https://v.daum.net/v/20230802170112132
# https://v.daum.net/v/20230802170112132
# https://v.daum.net/v/20230802161751447
# https://v.daum.net/v/20230802161751447
# https://v.daum.net/v/20230802170037100
# https://v.daum.net/v/20230802170037100
# https://v.daum.net/v/20230802142325466
# https://v.daum.net/v/20230802142325466
# https://v.daum.net/v/20230802160225758
# ...

# %%
for i in soup.find_all('div', {"class":"item_issue"}):
    print(i.find_all('a')[0].get('href'))
# Out:
# https://v.daum.net/v/20230802143727119
# https://v.daum.net/v/20230802165131730
# https://v.daum.net/v/20230802165849024
# https://v.daum.net/v/20230802150015227
# https://v.daum.net/v/20230802170112132
# https://v.daum.net/v/20230802161751447
# https://v.daum.net/v/20230802170037100
# https://v.daum.net/v/20230802142325466
# https://v.daum.net/v/20230802160225758
# https://v.daum.net/v/20230802161846502
# https://v.daum.net/v/20230802170154155
# https://v.daum.net/v/20230802170108126
# https://v.daum.net/v/20230802171404522
# https://v.daum.net/v/20230802170418234
# https://v.daum.net/v/20230802170006068
# https://v.daum.net/v/20230802171316499
# https://v.daum.net/v/20230802170801324
# https://v.daum.net/v/20230802160625941
# https://v.daum.net/v/20230802131527395
# https://v.daum.net/v/20230802171303488

# %%
linklist2 = soup.find_all('div', {"class":"item_issue"})
len(linklist2)
# Out:
# 20

# %%
newspaper = soup.find_all('div', {"class" : "item_issue"})

# %%
newspaper
# Out:
# [<div class="item_issue" data-tiara-layer="headline1">
#  <a class="wrap_thumb" data-tiara-custom="contentUniqueKey=hamny-20230802143727119&amp;clusterId=5000019,5590543,5201407,5201410,5150094&amp;clusterTitle=경제,[언론사픽] 주요뉴스,카테고리별,경제일반,경제&amp;keywordType=NONE,NONE,NONE,NONE,NONE" data-tiara-id="20230802143727119" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20230802143727119">
#  <img 1000원="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S96x60ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202308%2F02%2Fdailian%2F20230802143730183vyhx.jpg&amp;scode=media" “소주‧맥주="" 가격="" 마케팅="" 바뀌나"="" 방향="" 시대?”…주류업계=""/>
#  </a>
#  <div class="cont_thumb">
#  <span class="info_thumb">
#  <span class="logo_cp">
#  <img alt="데일리안" class="thumb_g" onerror="this.style.display='none';" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_dailian.gif"/>
#  </span>
#  <span class="txt_category">경제</span>
#  </span>
# ...

# %%
for i in newspaper:
    print(i.text, '\n')
# Out:
# 경제
#
#
#
#                                     “소주‧맥주 가격 1000원 시대?”…주류업계 마케팅 방향 바뀌나
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     감사원, 방통위, 경찰까지···MBC 대주주 방문진 전방위 압박하는 정부
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     “내가 낸 세금으로 먹고살잖아” 폭언·폭행에 피멍 드는 공무원들
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     [ET뷰]대학기술지주회사 투자회사 1500개 넘어...운영체제 혁신 필요
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     [스페셜리포트]연합형 기술지주회사, 지자체·대학 협력 기반 되려면
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     "들개 떼에 호신용품까지"...검단신도시 '집중 출몰' 이유는?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 사회
#
#
#
#                                     '양식장 떼죽음' 116억 악몽…펄펄 끓는 부산~전남 앞바다 비상
#
#
#
#
#
#
#
#
#
#
#
#
# 경기일보
#
# 문화
#
#
#
#                                     폭염경보... 붐비는 '무료 급식소'  [포토뉴스]
#
#
#
#
#
#
#
#
#
#
#
#
# 경기일보
#
# 사회
#
#
#
#                                     수도권 보훈대상자, 철도운임 무임 지원 대상 확대
#
# ...

# %%
ur.urlopen(i.find_all('a')[0].get('href')).read()
# Out:
# b'<!doctype html>\n<html class="os_window"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no"> \n  <meta name="format-detection" content="telephone=no"> \n  <meta name="referrer" content="unsafe-url"> \n  <title>\xec\xb5\x9c\xeb\x8c\x80 \xec\x88\x9c\xec\x9d\xb5 \xeb\x82\xb8 \xec\xb9\xb4\xec\xb9\xb4\xec\x98\xa4\xeb\xb1\x85\xed\x81\xac "\xea\xb1\xb4\xea\xb0\x95\xed\x95\x98\xea\xb2\x8c \xeb\x8c\x80\xec\xb6\x9c \xeb\xb6\x88\xeb\xa0\xb8\xeb\x8b\xa4"</title> \n  <link rel="shortcut icon" href="//t1.daumcdn.net/top/favicon.ico"> \n  <meta property="mccp:docId" content="BBD9AtdYMK"> \n  <meta property="og:site_name" content="\xec\x96\xb8\xeb\xa1\xa0\xec\x82\xac \xeb\xb7\xb0"> \n  <meta property="og:title" content="\xec\xb5\x9c\xeb\x8c\x80 \xec\x88\x9c\xec\x9d\xb5 \xeb\x82\xb8 \xec\xb9\xb4\xec\xb9\xb4\xec\x98\xa4\xeb\xb1\x8
# ...

# %%
soupc = bs(ur.urlopen(i.find_all('a')[0].get('href')).read(), 'html.parser')

# %%
soupc
# Out:
# <!DOCTYPE html>
#
# <html class="os_window">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>최대 순익 낸 카카오뱅크 "건강하게 대출 불렸다"</title>
# <link href="//t1.daumcdn.net/top/favicon.ico" rel="shortcut icon"/>
# <meta content="BBD9AtdYMK" property="mccp:docId"/>
# <meta content="언론사 뷰" property="og:site_name"/>
# <meta content='최대 순익 낸 카카오뱅크 "건강하게 대출 불렸다"' property="og:title"/>
# <meta content="20230802171303" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="비즈워치" property="og:article:author"/>
# <meta content="https://v.daum.net/v/20230802171303488" property="og:url"/>
# ...

# %%
bbb = []

for j in soupc.find_all('p'):
    bbb.append(j.text)

# %%
bbb
# Out:
# ['이 글자크기로 변경됩니다.',
#  '(예시) 가장 빠른 뉴스가 있고 다양한 정보, 쌍방향 소통이 숨쉬는 다음뉴스를 만나보세요. 다음뉴스는 국내외 주요이슈와 실시간 속보, 문화생활 및 다양한 분야의 뉴스를 입체적으로 전달하고 있습니다.',
#  '카카오뱅크가 올해 상반기 다시 한번 반기 기준 최고 실적을 갈아치웠다. 대출자산 성장에 힘입어 이자수익이 큰 폭으로 증가한 영향이다. 카카오뱅크가 당초 기대를 뛰어넘는\xa0대출 증가세를 고려해 10% 중반으로 잡았던 올해 대출 성장 목표치를 30% 넘는 수준으로 상향 조정했다.',
#  '은행권에서는 이례적으로 연체율도 개선했다. 중저신용자에게 공급한 신용대출 규모를\xa0역대 최대 규모로 늘리면서도\xa0건전성 지표를 개선한 것이 더욱 고무적이라는 평가다.\xa0',
#  '상반기 역대 최대 실적…여신 기여도 ↑',
#  '',
#  '카카오뱅크는 올해 2분기 당기순이익 820억원으로 작년 동기(570억원) 대비 43.9%(250억원) 증가했다고 2일 밝혔다. 1분기와 합친 상반기 전체 순이익은 1838억원으로 반기 기준 역대 최고 실적을 냈다. 이는 전년비 48.5% 늘어난 것이다.',
#  '실적 증가는\xa0여신 잔액 증가가 가장 큰 몫을 했다. 카카오뱅크의 2분기 말 여신 잔액은 약 33조9000억원으로 전 분기 말(29조3000억원) 대비 약 16% 늘었다. 올해 2분기 △개인신용대출\xa0△마이너스통장 △전월세대출 △주택담보대출 △개인사업자대출 등 모든 여신 상품의 잔액이 증가한 영향이다.',
#  '특히 2분기 말 기준 주택담보대출 잔액은 약 5조5000억원으로 전 분기 말 2조4000억원에 비해 3조1000억원 늘어났다. 2분기 주담대 신규 취급액은 약 3조5290억원으로 이중 약 60%가 대환 목적 유입됐다.\xa0기존 주담대를 보유하고 있는 소비자들이 시중은행 대비 낮은 금리에 카카오뱅크로 대환 것으로 분석된다.',
# ...

# %% [markdown]
# # 논문 Topic Modeling

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pdf 파일 읽어오기
#
# !pip install pypdf2
#
# !pip install tika

# %%
# !pip install pypdf2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# !pip install tika
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32624 sha256=52851efac5b61656dee6f2e9503a19d27b45b387b3c5b7fb609231b3fe86e8fe
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built tika
# ...

# %%
from tika import parser

pdf1 = parser.from_file("/content/EfficientNet.pdf")
# Out:
# 2023-08-02 08:24:38,845 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# 2023-08-02 08:24:39,322 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# 2023-08-02 08:24:39,694 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# WARNING:tika.tika:Failed to see startup log message; retrying...
# ...

# %%
pdf1['content'].strip().split('\n')
# Out:
# ['EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks',
#  '',
#  '',
#  'EfficientNet: Rethinking Model Scaling for Convolutional Neural Networks',
#  '',
#  'Mingxing Tan 1 Quoc V. Le 1',
#  '',
#  'Abstract',
#  'Convolutional Neural Networks (ConvNets) are',
#  'commonly developed at a fixed resource budget,',
#  'and then scaled up for better accuracy if more',
#  'resources are available. In this paper, we sys-',
#  'tematically study model scaling and identify that',
#  'carefully balancing network depth, width, and res-',
#  'olution can lead to better performance. Based',
#  'on this observation, we propose a new scaling',
#  'method that uniformly scales all dimensions of',
#  'depth/width/resolution using a simple yet highly',
#  'effective compound coefficient. We demonstrate',
#  'the effectiveness of this method on scaling up',
#  'MobileNets and ResNet.',
#  '',
#  'To go even further, we use neural architec-',
# ...

# %%
from PyPDF2 import PdfReader

pdf1 = PdfReader(open("/content/EfficientNet.pdf", 'rb'))
print(" No. Of Pages :", len(pdf1.pages))
# Out:
#  No. Of Pages : 11

# %%
total = ''
for i in range(len(pdf1.pages)):
    data = pdf1.pages[i].extract_text()
    total += data
print(total)
# Out:
# EfﬁcientNet: Rethinking Model Scaling for Convolutional Neural Networks
# Mingxing Tan1Quoc V . Le1
# Abstract
# Convolutional Neural Networks (ConvNets) are
# commonly developed at a ﬁxed resource budget,
# and then scaled up for better accuracy if more
# resources are available. In this paper, we sys-
# tematically study model scaling and identify that
# carefully balancing network depth, width, and res-
# olution can lead to better performance. Based
# on this observation, we propose a new scaling
# method that uniformly scales all dimensions of
# depth/width/resolution using a simple yet highly
# effective compound coefﬁcient . We demonstrate
# the effectiveness of this method on scaling up
# MobileNets and ResNet.
# To go even further, we use neural architec-
# ture search to design a new baseline network
# and scale it up to obtain a family of models,
# called EfﬁcientNets , which achieve much
# better accuracy and efﬁciency than previous
# ...

# %%
# Pdf 파일 txt파일로 변환
with open('EfficientNet.txt', 'w') as f:
    f.write(total)

# %%
# !pip install wordcloud

# %%
# !pip install konlpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 45.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 32.5 MB/s eta 0:00:00
# ...

# %%
text = open('EfficientNet.txt').read()
text
# Out:
# 'EfﬁcientNet: Rethinking Model Scaling for Convolutional Neural Networks\nMingxing Tan1Quoc V . Le1\nAbstract\nConvolutional Neural Networks (ConvNets) are\ncommonly developed at a ﬁxed resource budget,\nand then scaled up for better accuracy if more\nresources are available. In this paper, we sys-\ntematically study model scaling and identify that\ncarefully balancing network depth, width, and res-\nolution can lead to better performance. Based\non this observation, we propose a new scaling\nmethod that uniformly scales all dimensions of\ndepth/width/resolution using a simple yet highly\neffective compound coefﬁcient . We demonstrate\nthe effectiveness of this method on scaling up\nMobileNets and ResNet.\nTo go even further, we use neural architec-\nture search to design a new baseline network\nand scale it up to obtain a family of models,\ncalled EfﬁcientNets , which achieve much\nbetter accuracy and efﬁciency than previous\nConvNets. In particular, our EfﬁcientNet-B7\nachieves sta
# ...

# %%
import nltk
import pickle
from nltk.corpus import stopwords
import re
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
cleaned_content = re.sub(r'[^\.\?\!\w\d\s]','',text) # 문장단위로 끊기
print(cleaned_content)
# Out:
# EfﬁcientNet Rethinking Model Scaling for Convolutional Neural Networks
# Mingxing Tan1Quoc V . Le1
# Abstract
# Convolutional Neural Networks ConvNets are
# commonly developed at a ﬁxed resource budget
# and then scaled up for better accuracy if more
# resources are available. In this paper we sys
# tematically study model scaling and identify that
# carefully balancing network depth width and res
# olution can lead to better performance. Based
# on this observation we propose a new scaling
# method that uniformly scales all dimensions of
# depthwidthresolution using a simple yet highly
# effective compound coefﬁcient . We demonstrate
# the effectiveness of this method on scaling up
# MobileNets and ResNet.
# To go even further we use neural architec
# ture search to design a new baseline network
# and scale it up to obtain a family of models
# called EfﬁcientNets  which achieve much
# better accuracy and efﬁciency than previous
# ConvNets. In particular our EfﬁcientNetB7
# ...

# %%
# 대소문자 변환
cleaned_content = cleaned_content.lower()

# %%
# 단어 토큰화
word_tokens = nltk.word_tokenize(cleaned_content)
print(word_tokens)
# Out:
# ['efﬁcientnet', 'rethinking', 'model', 'scaling', 'for', 'convolutional', 'neural', 'networks', 'mingxing', 'tan1quoc', 'v', '.', 'le1', 'abstract', 'convolutional', 'neural', 'networks', 'convnets', 'are', 'commonly', 'developed', 'at', 'a', 'ﬁxed', 'resource', 'budget', 'and', 'then', 'scaled', 'up', 'for', 'better', 'accuracy', 'if', 'more', 'resources', 'are', 'available', '.', 'in', 'this', 'paper', 'we', 'sys', 'tematically', 'study', 'model', 'scaling', 'and', 'identify', 'that', 'carefully', 'balancing', 'network', 'depth', 'width', 'and', 'res', 'olution', 'can', 'lead', 'to', 'better', 'performance', '.', 'based', 'on', 'this', 'observation', 'we', 'propose', 'a', 'new', 'scaling', 'method', 'that', 'uniformly', 'scales', 'all', 'dimensions', 'of', 'depthwidthresolution', 'using', 'a', 'simple', 'yet', 'highly', 'effective', 'compound', 'coefﬁcient', '.', 'we', 'demonstrate', 'the', 'effectiveness', 'of', 'this', 'method', 'on', 'scaling', 'up', 'mobilenets', 'and', 'resnet
# ...

# %%
# 품사 분리
# pos_tag()의 입력값으로는 단어의 리스트가 들어가야 한다.
tokens_pos = nltk.pos_tag(word_tokens)
print(tokens_pos)
# Out:
# [('efﬁcientnet', 'NN'), ('rethinking', 'VBG'), ('model', 'NN'), ('scaling', 'VBG'), ('for', 'IN'), ('convolutional', 'JJ'), ('neural', 'JJ'), ('networks', 'NNS'), ('mingxing', 'VBG'), ('tan1quoc', 'NN'), ('v', 'NN'), ('.', '.'), ('le1', 'JJ'), ('abstract', 'JJ'), ('convolutional', 'JJ'), ('neural', 'JJ'), ('networks', 'NNS'), ('convnets', 'NNS'), ('are', 'VBP'), ('commonly', 'RB'), ('developed', 'VBN'), ('at', 'IN'), ('a', 'DT'), ('ﬁxed', 'JJ'), ('resource', 'NN'), ('budget', 'NN'), ('and', 'CC'), ('then', 'RB'), ('scaled', 'VBD'), ('up', 'RP'), ('for', 'IN'), ('better', 'JJR'), ('accuracy', 'NN'), ('if', 'IN'), ('more', 'JJR'), ('resources', 'NNS'), ('are', 'VBP'), ('available', 'JJ'), ('.', '.'), ('in', 'IN'), ('this', 'DT'), ('paper', 'NN'), ('we', 'PRP'), ('sys', 'VBP'), ('tematically', 'RB'), ('study', 'JJ'), ('model', 'NN'), ('scaling', 'NN'), ('and', 'CC'), ('identify', 'VB'), ('that', 'DT'), ('carefully', 'RB'), ('balancing', 'VBG'), ('network', 'NN'), ('depth', 'NN'), ('widt
# ...

# %%
# 명사 추출
# 명사는 NN을 포함하고 있음을 알 수 있음
NN_words = []
for word, pos in tokens_pos:
    if 'NN' in pos:
        NN_words.append(word)
print(NN_words)
# Out:
# ['efﬁcientnet', 'model', 'networks', 'tan1quoc', 'v', 'networks', 'convnets', 'resource', 'budget', 'accuracy', 'resources', 'paper', 'model', 'scaling', 'network', 'depth', 'width', 'olution', 'performance', 'observation', 'scaling', 'method', 'scales', 'dimensions', 'depthwidthresolution', 'compound', 'coefﬁcient', 'effectiveness', 'method', 'mobilenets', 'resnet', 'ture', 'search', 'baseline', 'network', 'scale', 'family', 'models', 'efﬁcientnets', 'accuracy', 'efﬁciency', 'convnets', 'achieves', 'accuracy', 'imagenet', 'faster', 'inference', 'convnet', 'efﬁcientnets', 'stateoftheart', 'accuracy', 'cifar100', 'flowers', 'transfer', 'datasets', 'order', 'magnitude', 'parameters', 'source', 'code', 'mastermodelsofficialefficientnet', 'introduction', 'convnets', 'accu', 'racy', 'example', 'resnet', 'resnet18', 'layers', 'huang', 'et', 'al', 'genet', 'top1', 'accuracy', 'baseline', 'model', 'research', 'brain', 'team', 'mountain', 'view', 'spondence', 'tanmingxinggoogle.com', 'proceed
# ...

# %%
# 원형(같은 의미 다른 단어 하나의 값으로 인지) 찾기

# nltk에서 제공되는 WordNetLemmatizer을 이용
# ex) 명사의 경우는 보통 복수 -> 단수 형태로 변형

wlem = nltk.WordNetLemmatizer()
lemmatized_words = []
for word in NN_words:
    new_word = wlem.lemmatize(word)
    lemmatized_words.append(new_word)

print(lemmatized_words)
# Out:
# ['efﬁcientnet', 'model', 'network', 'tan1quoc', 'v', 'network', 'convnets', 'resource', 'budget', 'accuracy', 'resource', 'paper', 'model', 'scaling', 'network', 'depth', 'width', 'olution', 'performance', 'observation', 'scaling', 'method', 'scale', 'dimension', 'depthwidthresolution', 'compound', 'coefﬁcient', 'effectiveness', 'method', 'mobilenets', 'resnet', 'ture', 'search', 'baseline', 'network', 'scale', 'family', 'model', 'efﬁcientnets', 'accuracy', 'efﬁciency', 'convnets', 'achieves', 'accuracy', 'imagenet', 'faster', 'inference', 'convnet', 'efﬁcientnets', 'stateoftheart', 'accuracy', 'cifar100', 'flower', 'transfer', 'datasets', 'order', 'magnitude', 'parameter', 'source', 'code', 'mastermodelsofficialefficientnet', 'introduction', 'convnets', 'accu', 'racy', 'example', 'resnet', 'resnet18', 'layer', 'huang', 'et', 'al', 'genet', 'top1', 'accuracy', 'baseline', 'model', 'research', 'brain', 'team', 'mountain', 'view', 'spondence', 'tanmingxinggoogle.com', 'proceeding', 'co
# ...

# %%
# 불용어 제거

stopwords_list = stopwords.words('english') #nltk에서 제공하는 불용어사전 이용
#print('stopwords: ', stopwords_list)
unique_NN_words = set(lemmatized_words)
final_NN_words = lemmatized_words

for word in unique_NN_words:
    if word in stopwords_list:
        while word in final_NN_words: final_NN_words.remove(word)

# %%
# 빈도 분석

from collections import Counter
c = Counter(final_NN_words) # input type should be a list of words (or tokens)
print(c)
k = 40
print(c.most_common(k)) # 빈도수 기준 상위 k개 단어 출력
# Out:
# Counter({'al': 105, 'model': 89, 'network': 85, 'accuracy': 62, 'et': 56, 'resolution': 43, 'method': 32, 'flop': 32, 'depth': 31, 'baseline': 31, 'convnets': 29, 'a.': 26, 'compound': 24, 'scaling': 22, 'width': 22, 'scale': 22, 'j.': 21, 'dimension': 20, 'huang': 20, 'efﬁcientnet': 19, 'v': 19, 'parameter': 19, 'layer': 19, 'image': 19, 'search': 17, 'imagenet': 17, 'figure': 17, 'architecture': 17, 's.': 16, 'm.': 16, 'zoph': 15, 'pp': 15, 'gpipe': 14, 'szegedy': 14, 'efﬁciency': 13, 'acc': 13, 'size': 13, 'result': 13, 'transfer': 12, 'efﬁcientnetb7': 12, 'd.': 12, 'cvpr': 12, 'convnet': 11, 'datasets': 11, 'top1': 11, 'b.': 11, 'z.': 11, 'resource': 10, 'order': 10, 'efﬁcientnetb0': 10, 'q.': 10, 'efﬁcientnets': 9, 'way': 9, 'work': 9, 'h.': 9, 'paper': 8, 'example': 8, 'channel': 8, 'preprint': 8, 'performance': 7, 'mobilenets': 7, 'resnet': 7, 'learning': 7, 'hu': 7, 'resnet50': 7, 'validation': 7, 'design': 7, 'lin': 7, 'problem': 7, 'feature': 7, 'w.': 7, 'latency': 7, 'test
# ...

# %%
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120500 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-3_all.deb ...
# Unpacking fonts-nanum-coding (2.5-3) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# Unpacking fonts-nanum-eco (1.000-7) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20200506-1_all.deb ...
# Unpacking fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum-extra (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Setting up fonts-nanum-coding (2.5-3) ...
# Setting up fonts-nanum-eco (1.000-7) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# 폰트 경로 확인
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()

[f for f in sys_font if 'Nanum' in f]
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumBarunpenB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquare_acR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquare_acB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundL.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEcoR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumPen.ttf',
# ...

# %%
# 워드클라우드

import wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

FONT_PATH = '/usr/share/fonts/truetype/nanum/NanumBarunGothic-YetHangul.ttf'

noun_text = ''
for word in final_NN_words:
    noun_text = noun_text +' '+word

wordcloud = WordCloud(max_font_size=60, relative_scaling=.5, font_path=FONT_PATH, background_color='white').generate(noun_text) # generate() 는 하나의 string value를 입력 받음
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("wordcloud_EfficientNet2.png")

# %%
final_NN_words
# Out:
# ['efﬁcientnet',
#  'model',
#  'network',
#  'tan1quoc',
#  'v',
#  'network',
#  'convnets',
#  'resource',
#  'budget',
#  'accuracy',
#  'resource',
#  'paper',
#  'model',
#  'scaling',
#  'network',
#  'depth',
#  'width',
#  'olution',
#  'performance',
#  'observation',
#  'scaling',
#  'method',
#  'scale',
#  'dimension',
#  'depthwidthresolution',
#  'compound',
#  'coefﬁcient',
#  'effectiveness',
#  'method',
#  'mobilenets',
#  'resnet',
#  'ture',
#  'search',
#  'baseline',
#  'network',
#  'scale',
#  'family',
#  'model',
#  'efﬁcientnets',
#  'accuracy',
#  'efﬁciency',
#  'convnets',
#  'achieves',
#  'accuracy',
#  'imagenet',
#  'faster',
#  'inference',
#  'convnet',
#  'efﬁcientnets',
#  'stateoftheart',
#  'accuracy',
#  'cifar100',
#  'flower',
#  'transfer',
#  'datasets',
#  'order',
#  'magnitude',
#  'parameter',
#  'source',
#  'code',
#  'mastermodelsofficialefficientnet',
#  'introduction',
#  'convnets',
#  'accu',
#  'racy',
#  'example',
# ...

# %%
with open('EfficientNet_words.txt', 'w') as f:
        for data in final_NN_words:
            f.write(data)

# %% [markdown]
# ## LDA 토픽 모델링

# %%
# !pip install gensim

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
#LDA 는 Count기반의 Vectorizer만 적용
count_vectorizer = CountVectorizer(max_df=0.1, max_features=1000, min_df=2, ngram_range=(1,2))
    # 2개의 문서 미만으로 등장하는 단어는 제외, 전체의 10% 이상으로 자주 등장하는 단어는 제외
    # bigram도 포함

feat_vect = count_vectorizer.fit_transform(tokenized_list)
print('CountVectorizer Shape:', feat_vect.shape)
